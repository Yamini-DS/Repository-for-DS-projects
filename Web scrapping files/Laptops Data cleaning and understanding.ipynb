# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import pandas as pd
import numpy as np
import re

# %%
L1 = pd.read_csv("Web scrapping csv")
L1
# Out:
#      Unnamed: 0                                             Laptop  Rating  \
# 0             0  Acer Predator Helios 300 Core i5 8th Gen - (8 ...     4.6
# 1             1  MSI GS Core i7 8th Gen - (16 GB/512 GB SSD/Win...     4.0
# 2             2  Asus FX503 Core i7 7th Gen - (8 GB/1 TB HDD/12...     5.0
# 3             3  Asus TUF Core i5 8th Gen - (8 GB/1 TB HDD/128 ...     4.5
# 4             4  MSI GE Core i7 8th Gen - (16 GB/1 TB HDD/512 G...     4.5
# 5             5  Asus ROG Strix Edition Core i7 7th Gen - (8 GB...     4.0
# 6             6  Asus ROG Core i7 7th Gen - (8 GB/1 TB HDD/Wind...     4.3
# 7             7  Asus ROG Core i7 7th Gen - (8 GB/1 TB HDD/256 ...     3.0
# 8             8  Acer Predator Helios 300 Core i5 7th Gen - (8 ...     4.5
# 9             9  MSI GL Series Core i7 7th Gen - (8 GB/1 TB HDD...     4.9
# 10           10  Acer Nitro 5 Core i5 7th Gen - (8 GB/1 TB HDD/...     4.5
# ...

# %%
L1.shape
# Out:
# (814, 11)

# %% [markdown]
# ## Data cleaning and understanding the data

# %% [markdown]
# > - There are 814 rows and 11 columns in my dataset.

# %%
print(L1['Brands'])
# Out:
# 0                              Acer Predator Helios 300
# 1                                                MSI GS
# 2                                            Asus FX503
# 3                                              Asus TUF
# 4                                                MSI GE
# 5                                Asus ROG Strix Edition
# 6                                              Asus ROG
# 7                                              Asus ROG
# 8                              Acer Predator Helios 300
# 9                                         MSI GL Series
# 10                                         Acer Nitro 5
# 11                                             Asus TUF
# 12                                        MSI GV Series
# 13                                           Asus FX553
# 14                                        Lenovo Legion
# 15                                               MSI GL
# 16                               Asus ROG Strix Edition
# ...

# %%
L1['Processor']
# Out:
# 0        i5 8th Gen
# 1        i7 8th Gen
# 2        i7 7th Gen
# 3        i5 8th Gen
# 4        i7 8th Gen
# 5        i7 7th Gen
# 6        i7 7th Gen
# 7        i7 7th Gen
# 8        i5 7th Gen
# 9        i7 7th Gen
# 10       i5 7th Gen
# 11       i5 8th Gen
# 12       i7 8th Gen
# 13       i7 7th Gen
# 14       i5 7th Gen
# 15       i7 8th Gen
# 16       i7 8th Gen
# 17       i5 5th Gen
# 18       i7 9th Gen
# 19       i5 8th Gen
# 20     Dual Core A9
# 21       i5 8th Gen
# 22       i3 7th Gen
# 23       i5 9th Gen
# 24       i3 7th Gen
# 25       i5 8th Gen
# 26      3 Dual Core
# 27       i5 8th Gen
# 28       i5 8th Gen
# 29       i3 7th Gen
#            ...
# 784      i5 8th Gen
# 785      i5 8th Gen
# 786      i5 7th Gen
# 787      i5 7th Gen
# 788             NaN
# 789      i5 8th Gen
# 790      i7 9th Gen
# 791     i5 10th Gen
# 792      i5 8th Gen
# 793      i3 7th Gen
# 794             NaN
# 795      i7 9th Gen
# 796      i5 8th Gen
# 797             NaN
# ...

# %%
B=[]
C =[]
for i in L1['Brands']:
    d = list(i.split())
    B.append(d[0])
    a = ' '.join(d[1:])
    #if a:
    C.append(a)
    #print(a)
    #else:
     #   C.append(np.nan)
print(B)
print(C)
# Out:
# ['Acer', 'MSI', 'Asus', 'Asus', 'MSI', 'Asus', 'Asus', 'Asus', 'Acer', 'MSI', 'Acer', 'Asus', 'MSI', 'Asus', 'Lenovo', 'MSI', 'Asus', 'Apple', 'MSI', 'Acer', 'HP', 'Acer', 'Asus', 'MSI', 'Lenovo', 'HP', 'Acer', 'Dell', 'Dell', 'Dell', 'Lenovo', 'Dell', 'Acer', 'Acer', 'Lenovo', 'Acer', 'Asus', 'Lenovo', 'MSI', 'MSI', 'Avita', 'Dell', 'HP', 'HP', 'Acer', 'Asus', 'HP', 'Dell', 'Lenovo', 'Acer', 'Asus', 'Acer', 'Dell', 'Asus', 'Avita', 'Asus', 'HP', 'Lenovo', 'Asus', 'Lenovo', 'Asus', 'Asus', 'Asus', 'Avita', 'Asus', 'Asus', 'HP', 'Acer', 'HP', 'HP', 'Asus', 'Lenovo', 'Asus', 'Lenovo', 'Asus', 'MSI', 'HP', 'Dell', 'Acer', 'HP', 'Asus', 'Asus', 'Lenovo', 'HP', 'HP', 'Asus', 'Dell', 'HP', 'MSI', 'Acer', 'HP', 'Asus', 'Acer', 'HP', 'Lenovo', 'MSI', 'Asus', 'Avita', 'Asus', 'HP', 'HP', 'HP', 'HP', 'HP', 'Asus', 'Avita', 'Asus', 'HP', 'Avita', 'HP', 'Dell', 'Lenovo', 'Asus', 'Acer', 'Apple', 'Dell', 'MSI', 'HP', 'HP', 'Asus', 'Nexstgo', 'Acer', 'Asus', 'Dell', 'Dell', 'Acer', 'Alienware', 'D
# ...

# %%
type('Brands')
# Out:
# str

# %%
len(B)
# Out:
# 814

# %%
len(C)
# Out:
# 814

# %%
L1['Brands']=B

# %%
L1
# Out:
#      Unnamed: 0                                             Laptop  Rating  \
# 0             0  Acer Predator Helios 300 Core i5 8th Gen - (8 ...     4.6
# 1             1  MSI GS Core i7 8th Gen - (16 GB/512 GB SSD/Win...     4.0
# 2             2  Asus FX503 Core i7 7th Gen - (8 GB/1 TB HDD/12...     5.0
# 3             3  Asus TUF Core i5 8th Gen - (8 GB/1 TB HDD/128 ...     4.5
# 4             4  MSI GE Core i7 8th Gen - (16 GB/1 TB HDD/512 G...     4.5
# 5             5  Asus ROG Strix Edition Core i7 7th Gen - (8 GB...     4.0
# 6             6  Asus ROG Core i7 7th Gen - (8 GB/1 TB HDD/Wind...     4.3
# 7             7  Asus ROG Core i7 7th Gen - (8 GB/1 TB HDD/256 ...     3.0
# 8             8  Acer Predator Helios 300 Core i5 7th Gen - (8 ...     4.5
# 9             9  MSI GL Series Core i7 7th Gen - (8 GB/1 TB HDD...     4.9
# 10           10  Acer Nitro 5 Core i5 7th Gen - (8 GB/1 TB HDD/...     4.5
# ...

# %%
#if C:
 #   Model.append(C)
#else:
 #   Model.append(np.nan)

# %%
L1['Model']=C

# %%
L1
# Out:
#      Unnamed: 0                                             Laptop  Rating  \
# 0             0  Acer Predator Helios 300 Core i5 8th Gen - (8 ...     4.6
# 1             1  MSI GS Core i7 8th Gen - (16 GB/512 GB SSD/Win...     4.0
# 2             2  Asus FX503 Core i7 7th Gen - (8 GB/1 TB HDD/12...     5.0
# 3             3  Asus TUF Core i5 8th Gen - (8 GB/1 TB HDD/128 ...     4.5
# 4             4  MSI GE Core i7 8th Gen - (16 GB/1 TB HDD/512 G...     4.5
# 5             5  Asus ROG Strix Edition Core i7 7th Gen - (8 GB...     4.0
# 6             6  Asus ROG Core i7 7th Gen - (8 GB/1 TB HDD/Wind...     4.3
# 7             7  Asus ROG Core i7 7th Gen - (8 GB/1 TB HDD/256 ...     3.0
# 8             8  Acer Predator Helios 300 Core i5 7th Gen - (8 ...     4.5
# 9             9  MSI GL Series Core i7 7th Gen - (8 GB/1 TB HDD...     4.9
# 10           10  Acer Nitro 5 Core i5 7th Gen - (8 GB/1 TB HDD/...     4.5
# ...

# %%
#L1.drop(801,inplace=True)

# %%
L1.drop(columns='Unnamed: 0',inplace=True)

# %% [markdown]
# - I have dropped the unncessary column named Unnamed: 0 from my data for having better understanding.

# %%
L1
# Out:
#                                                 Laptop  Rating  Disc_price  \
# 0    Acer Predator Helios 300 Core i5 8th Gen - (8 ...     4.6       55990
# 1    MSI GS Core i7 8th Gen - (16 GB/512 GB SSD/Win...     4.0      149990
# 2    Asus FX503 Core i7 7th Gen - (8 GB/1 TB HDD/12...     5.0       87990
# 3    Asus TUF Core i5 8th Gen - (8 GB/1 TB HDD/128 ...     4.5       66990
# 4    MSI GE Core i7 8th Gen - (16 GB/1 TB HDD/512 G...     4.5      179990
# 5    Asus ROG Strix Edition Core i7 7th Gen - (8 GB...     4.0       92990
# 6    Asus ROG Core i7 7th Gen - (8 GB/1 TB HDD/Wind...     4.3      107990
# 7    Asus ROG Core i7 7th Gen - (8 GB/1 TB HDD/256 ...     3.0      146490
# 8    Acer Predator Helios 300 Core i5 7th Gen - (8 ...     4.5      129999
# 9    MSI GL Series Core i7 7th Gen - (8 GB/1 TB HDD...     4.9       83990
# 10   Acer Nitro 5 Core i5 7th Gen - (8 GB/1 TB HDD/...     4.5       52990
# ...

# %%
#L1.reset_index(inplace=True)

# %%
L1.rename(columns={"OS":"Operating system"},inplace=True)

# %% [markdown]
# - I have renamed my OS column to operating system

# %%
L1
# Out:
#                                                 Laptop  Rating  Disc_price  \
# 0    Acer Predator Helios 300 Core i5 8th Gen - (8 ...     4.6       55990
# 1    MSI GS Core i7 8th Gen - (16 GB/512 GB SSD/Win...     4.0      149990
# 2    Asus FX503 Core i7 7th Gen - (8 GB/1 TB HDD/12...     5.0       87990
# 3    Asus TUF Core i5 8th Gen - (8 GB/1 TB HDD/128 ...     4.5       66990
# 4    MSI GE Core i7 8th Gen - (16 GB/1 TB HDD/512 G...     4.5      179990
# 5    Asus ROG Strix Edition Core i7 7th Gen - (8 GB...     4.0       92990
# 6    Asus ROG Core i7 7th Gen - (8 GB/1 TB HDD/Wind...     4.3      107990
# 7    Asus ROG Core i7 7th Gen - (8 GB/1 TB HDD/256 ...     3.0      146490
# 8    Acer Predator Helios 300 Core i5 7th Gen - (8 ...     4.5      129999
# 9    MSI GL Series Core i7 7th Gen - (8 GB/1 TB HDD...     4.9       83990
# 10   Acer Nitro 5 Core i5 7th Gen - (8 GB/1 TB HDD/...     4.5       52990
# ...

# %%
#L1.drop(columns='index',inplace=True)

# %%
type('Rating')
type('Disc_price')
# Out:
# str
# str

# %%
type(L1['Disc_price'])
# Out:
# pandas.core.series.Series

# %%
for i in L1['No of Ratings']:
    type(i)
# Out:
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# float
# ...

# %%
L1['Disc_price'].mean()
# Out:
# 57935.174447174446

# %%
L1['Rating'].mean()
# Out:
# 4.208180535966148

# %%
L1['Disc_price'].sum()
# Out:
# 47159232

# %%
print(L1['No of Ratings'])
type(L1['No of Ratings'])
# Out:
# 0      11530.0
# 1          9.0
# 2          2.0
# 3       1181.0
# 4         13.0
# 5          5.0
# 6         29.0
# 7          2.0
# 8       3199.0
# 9         27.0
# 10       405.0
# 11        56.0
# 12       746.0
# 13       351.0
# 14       359.0
# 15       712.0
# 16       108.0
# 17     20868.0
# 18         NaN
# 19      3682.0
# 20      6948.0
# 21      2341.0
# 22      2830.0
# 23       476.0
# 24      3594.0
# 25      1679.0
# 26       753.0
# 27       189.0
# 28       260.0
# 29      2359.0
#         ...
# 784        1.0
# 785        8.0
# 786      225.0
# 787       19.0
# 788      911.0
# 789       13.0
# 790        4.0
# 791       10.0
# 792       23.0
# 793     9365.0
# 794    25279.0
# 795        NaN
# 796       39.0
# 797        6.0
# 798      381.0
# 799     1730.0
# 800        NaN
# 801      154.0
# 802      218.0
# 803      260.0
# 804      245.0
# 805        NaN
# 806        NaN
# 807    14498.0
# 808        4.0
# 809     1679.0
# 810      114.0
# 811        NaN
# ...

# %%
L1['No of Ratings']
# Out:
# 0      11530.0
# 1          9.0
# 2          2.0
# 3       1181.0
# 4         13.0
# 5          5.0
# 6         29.0
# 7          2.0
# 8       3199.0
# 9         27.0
# 10       405.0
# 11        56.0
# 12       746.0
# 13       351.0
# 14       359.0
# 15       712.0
# 16       108.0
# 17     20868.0
# 18         NaN
# 19      3682.0
# 20      6948.0
# 21      2341.0
# 22      2830.0
# 23       476.0
# 24      3594.0
# 25      1679.0
# 26       753.0
# 27       189.0
# 28       260.0
# 29      2359.0
#         ...
# 784        1.0
# 785        8.0
# 786      225.0
# 787       19.0
# 788      911.0
# 789       13.0
# 790        4.0
# 791       10.0
# 792       23.0
# 793     9365.0
# 794    25279.0
# 795        NaN
# 796       39.0
# 797        6.0
# 798      381.0
# 799     1730.0
# 800        NaN
# 801      154.0
# 802      218.0
# 803      260.0
# 804      245.0
# 805        NaN
# 806        NaN
# 807    14498.0
# 808        4.0
# 809     1679.0
# 810      114.0
# 811        NaN
# ...

# %%
L1.shape
# Out:
# (814, 11)

# %%
L1['No of Ratings'].sum()
# Out:
# 981554.0

# %%
L1['No of Reviews'].sum()
# Out:
# 142984.0

# %%
L1.describe()
# Out:
#            Rating     Disc_price  No of Ratings  No of Reviews     Ram[GB]
# count  709.000000     814.000000     709.000000     709.000000  812.000000
# mean     4.208181   57935.174447    1384.420310     201.669958    7.045567
# std      0.388050   45492.042654    2778.156358     399.591873    4.192841
# min      1.000000     299.000000       1.000000       0.000000    2.000000
# 25%      4.000000   28990.000000      31.000000       6.000000    4.000000
# 50%      4.200000   45990.000000     196.000000      31.000000    8.000000
# 75%      4.400000   68867.250000    1576.000000     227.000000    8.000000
# max      5.000000  399990.000000   25279.000000    3848.000000   32.000000

# %%
L1
# Out:
#                                                 Laptop  Rating  Disc_price  \
# 0    Acer Predator Helios 300 Core i5 8th Gen - (8 ...     4.6       55990
# 1    MSI GS Core i7 8th Gen - (16 GB/512 GB SSD/Win...     4.0      149990
# 2    Asus FX503 Core i7 7th Gen - (8 GB/1 TB HDD/12...     5.0       87990
# 3    Asus TUF Core i5 8th Gen - (8 GB/1 TB HDD/128 ...     4.5       66990
# 4    MSI GE Core i7 8th Gen - (16 GB/1 TB HDD/512 G...     4.5      179990
# 5    Asus ROG Strix Edition Core i7 7th Gen - (8 GB...     4.0       92990
# 6    Asus ROG Core i7 7th Gen - (8 GB/1 TB HDD/Wind...     4.3      107990
# 7    Asus ROG Core i7 7th Gen - (8 GB/1 TB HDD/256 ...     3.0      146490
# 8    Acer Predator Helios 300 Core i5 7th Gen - (8 ...     4.5      129999
# 9    MSI GL Series Core i7 7th Gen - (8 GB/1 TB HDD...     4.9       83990
# 10   Acer Nitro 5 Core i5 7th Gen - (8 GB/1 TB HDD/...     4.5       52990
# ...

# %%
L1['Laptop'].loc[780:840]
# Out:
# 780    MSI Core i9 9th Gen - (32 GB/1 TB HDD/1 TB SSD...
# 781    Lenovo Yoga 730 Core i5 8th Gen - (8 GB/512 GB...
# 782    Dell G3 Series Core i5 8th Gen - (8 GB/1 TB HD...
# 783    HP Omen Core i5 7th Gen - (8 GB/1 TB HDD/128 G...
# 784    Acer Spin Core i5 8th Gen - (8 GB/256 GB SSD/W...
# 785    Microsoft Surface Pro 6 Core i5 8th Gen - (8 G...
# 786    Microsoft Surface Pro Core i5 7th Gen - (4 GB/...
# 787    Microsoft Surface Core i5 7th Gen - (8 GB/128 ...
# 788    Microsoft Surface Go Pentium Gold - (4 GB/64 G...
# 789    Microsoft Surface Laptop 2 Core i5 8th Gen - (...
# 790    MSI Core i7 9th Gen - (16 GB/1 TB HDD/256 GB S...
# 791    HP Pavilion x360 Core i5 10th Gen - (8 GB/256 ...
# 792    Lenovo Ideapad 330 Core i5 8th Gen - (8 GB/1 T...
# 793    HP 14q Core i3 7th Gen - (4 GB/1 TB HDD/Window...
# 794     Flipkart SmartBuy KM-206W Wireless Optical Mouse
# 795    Acer NITRO 5 Core i7 9th Gen - (8 GB/1 TB HDD/...
# ...

# %%
L1.drop(807,inplace=True)

# %%
L1['Rating'].sum()
# Out:
# 2979.1

# %%
L1['Ram[GB]'].sum()
# Out:
# 5721.0

# %%
L1['Processor'].isnull().any()
# Out:
# True

# %%
L1['Processor'].value_counts()
# Out:
# i5 8th Gen              171
# i3 7th Gen              140
# i7 8th Gen               50
# i5 7th Gen               43
# i7 7th Gen               41
# i3 6th Gen               40
# i3 5th Gen               31
# i7 9th Gen               31
# i5 6th Gen               18
# i3 4th Gen               17
# i5 5th Gen               15
# i5 9th Gen               14
# i3 8th Gen               13
# i7 6th Gen               12
# Dual Core Processor4      8
# Dual Core Processor2      8
# i7 5th Gen                7
# i5 10th Gen               6
# Dual Core A9              6
# i7 4th Gen                6
# Dual Core E2              5
# i5 4th Gen                5
# i7 10th Gen               4
# Dual Core 4th             4
# Dual Core 5th             3
# i9 9th Gen                2
# Dual Core E1              2
# Dual Core A4              2
# Dual Core A6              2
# i7 Processor4 GB          2
# Dual Core 7th             1
# i5 3rd Gen                1
# 3 Dual Core               1
# ...

# %%
L1['Processor'].value_counts().sum()
# Out:
# 715

# %%
814-715
# Out:
# 99

# %%
L1.loc[801:814]
# Out:
#                                                 Laptop  Rating  Disc_price  \
# 801  Asus VivoBook S14 Core i7 8th Gen - (8 GB/1 TB...     4.7       84990
# 802  Lenovo Ideapad 130 Core i3 7th Gen - (4 GB/1 T...     4.0       27990
# 803  Dell G3 Series Core i5 8th Gen - (8 GB/1 TB HD...     4.4       54990
# 804  Asus X507UF Core i5 8th Gen - (8 GB/1 TB HDD/W...     4.4       41890
# 805  Dell Inspiron 3000 Ryzen 3 Quad Core - (4 GB/1...     NaN       35247
# 806  Asus ZenBook 14 Ryzen 5 Quad Core 3rd Gen - (8...     NaN       61990
# 808  Asus Core i7 8th Gen - (8 GB/1 TB HDD/256 GB S...     4.0       56890
# 809  HP Pavilion 15 Core i5 8th Gen - (8 GB/1 TB HD...     4.3       49990
# 810  Avita Liber Core i5 7th Gen - (8 GB/256 GB SSD...     4.4       42990
# 811  MSI Core i7 9th Gen - (16 GB/1 TB SSD/Windows ...     NaN      214990
# 812  Lenovo Core i5 7th Gen - (8 GB/1 TB HDD/Window...     4.1       64715
# ...

# %%
L1.drop(794,inplace=True)

# %% [markdown]
# - Firstly i have taken a brief description about the statistics for the numerical data by using describe() method
# - I have dropped some unnecessary data which cannot be used in my analysis like some extra products we get for using laptops like mouse and adapter
# - I found the no of laptops in particular brands used in my analysis
# - Now we have readjusted and cleaned the data.
# - After cleaning we have 812 rows and 11 columns.

# %%
L1.reset_index(inplace=True)
L1
# Out:
#      index                                             Laptop  Rating  \
# 0        0  Acer Predator Helios 300 Core i5 8th Gen - (8 ...     4.6
# 1        1  MSI GS Core i7 8th Gen - (16 GB/512 GB SSD/Win...     4.0
# 2        2  Asus FX503 Core i7 7th Gen - (8 GB/1 TB HDD/12...     5.0
# 3        3  Asus TUF Core i5 8th Gen - (8 GB/1 TB HDD/128 ...     4.5
# 4        4  MSI GE Core i7 8th Gen - (16 GB/1 TB HDD/512 G...     4.5
# 5        5  Asus ROG Strix Edition Core i7 7th Gen - (8 GB...     4.0
# 6        6  Asus ROG Core i7 7th Gen - (8 GB/1 TB HDD/Wind...     4.3
# 7        7  Asus ROG Core i7 7th Gen - (8 GB/1 TB HDD/256 ...     3.0
# 8        8  Acer Predator Helios 300 Core i5 7th Gen - (8 ...     4.5
# 9        9  MSI GL Series Core i7 7th Gen - (8 GB/1 TB HDD...     4.9
# 10      10  Acer Nitro 5 Core i5 7th Gen - (8 GB/1 TB HDD/...     4.5
# 11      11  Asus TUF Core i5 8th Gen - (8 GB/1 TB HDD/128 ...     4.3
# ...

# %%
L1.drop(columns={'index'},inplace=True)
L1
# Out:
#                                                 Laptop  Rating  Disc_price  \
# 0    Acer Predator Helios 300 Core i5 8th Gen - (8 ...     4.6       55990
# 1    MSI GS Core i7 8th Gen - (16 GB/512 GB SSD/Win...     4.0      149990
# 2    Asus FX503 Core i7 7th Gen - (8 GB/1 TB HDD/12...     5.0       87990
# 3    Asus TUF Core i5 8th Gen - (8 GB/1 TB HDD/128 ...     4.5       66990
# 4    MSI GE Core i7 8th Gen - (16 GB/1 TB HDD/512 G...     4.5      179990
# 5    Asus ROG Strix Edition Core i7 7th Gen - (8 GB...     4.0       92990
# 6    Asus ROG Core i7 7th Gen - (8 GB/1 TB HDD/Wind...     4.3      107990
# 7    Asus ROG Core i7 7th Gen - (8 GB/1 TB HDD/256 ...     3.0      146490
# 8    Acer Predator Helios 300 Core i5 7th Gen - (8 ...     4.5      129999
# 9    MSI GL Series Core i7 7th Gen - (8 GB/1 TB HDD...     4.9       83990
# 10   Acer Nitro 5 Core i5 7th Gen - (8 GB/1 TB HDD/...     4.5       52990
# ...

# %%
L1.drop(columns='Laptop',inplace=True)
L1
# Out:
#      Rating  Disc_price  No of Ratings  No of Reviews     Processor  Ram[GB]  \
# 0       4.6       55990        11530.0         1566.0    i5 8th Gen      8.0
# 1       4.0      149990            9.0            2.0    i7 8th Gen     16.0
# 2       5.0       87990            2.0            1.0    i7 7th Gen      8.0
# 3       4.5       66990         1181.0          219.0    i5 8th Gen      8.0
# 4       4.5      179990           13.0            3.0    i7 8th Gen     16.0
# 5       4.0       92990            5.0            2.0    i7 7th Gen      8.0
# 6       4.3      107990           29.0           11.0    i7 7th Gen      8.0
# 7       3.0      146490            2.0            1.0    i7 7th Gen      8.0
# 8       4.5      129999         3199.0          697.0    i5 7th Gen      8.0
# 9       4.9       83990           27.0           11.0    i7 7th Gen      8.0
# 10      4.5       52990          405.0           83.0    i5 7th Gen      8.0
# ...

# %%
columns=['Brands','Ram[GB]','Storage','Processor','Model','Rating','Disc_price','No of Ratings','No of Reviews','Operating system']
L1 = L1[columns]
L1
# Out:
#         Brands  Ram[GB]              Storage     Processor  \
# 0         Acer      8.0  1 TB HDD 128 GB SSD    i5 8th Gen
# 1          MSI     16.0           512 GB SSD    i7 8th Gen
# 2         Asus      8.0  1 TB HDD 128 GB SSD    i7 7th Gen
# 3         Asus      8.0  1 TB HDD 128 GB SSD    i5 8th Gen
# 4          MSI     16.0  1 TB HDD 512 GB SSD    i7 8th Gen
# 5         Asus      8.0  1 TB HDD 128 GB SSD    i7 7th Gen
# 6         Asus      8.0             1 TB HDD    i7 7th Gen
# 7         Asus      8.0  1 TB HDD 256 GB SSD    i7 7th Gen
# 8         Acer      8.0  1 TB HDD 128 GB SSD    i5 7th Gen
# 9          MSI      8.0  1 TB HDD 128 GB SSD    i7 7th Gen
# 10        Acer      8.0  1 TB HDD 128 GB SSD    i5 7th Gen
# 11        Asus      8.0  1 TB HDD 128 GB SSD    i5 8th Gen
# 12         MSI     16.0  1 TB HDD 128 GB SSD    i7 8th Gen
# 13        Asus      8.0             1 TB HDD    i7 7th Gen
# 14      Lenovo      8.0  1 TB HDD 128 GB SSD    i5 7th Gen
# ...

# %%
L1
# Out:
#         Brands  Ram[GB]              Storage     Processor  \
# 0         Acer      8.0  1 TB HDD 128 GB SSD    i5 8th Gen
# 1          MSI     16.0           512 GB SSD    i7 8th Gen
# 2         Asus      8.0  1 TB HDD 128 GB SSD    i7 7th Gen
# 3         Asus      8.0  1 TB HDD 128 GB SSD    i5 8th Gen
# 4          MSI     16.0  1 TB HDD 512 GB SSD    i7 8th Gen
# 5         Asus      8.0  1 TB HDD 128 GB SSD    i7 7th Gen
# 6         Asus      8.0             1 TB HDD    i7 7th Gen
# 7         Asus      8.0  1 TB HDD 256 GB SSD    i7 7th Gen
# 8         Acer      8.0  1 TB HDD 128 GB SSD    i5 7th Gen
# 9          MSI      8.0  1 TB HDD 128 GB SSD    i7 7th Gen
# 10        Acer      8.0  1 TB HDD 128 GB SSD    i5 7th Gen
# 11        Asus      8.0  1 TB HDD 128 GB SSD    i5 8th Gen
# 12         MSI     16.0  1 TB HDD 128 GB SSD    i7 8th Gen
# 13        Asus      8.0             1 TB HDD    i7 7th Gen
# 14      Lenovo      8.0  1 TB HDD 128 GB SSD    i5 7th Gen
# ...

# %% [markdown]
# - In the Laptops data, the columns have been repositioned.

# %%
L1.sort_values(by='Rating',ascending=True)
# Out:
#         Brands  Ram[GB]                  Storage             Processor  \
# 314     Lenovo      8.0               256 GB SSD            i7 7th Gen
# 277       Dell      8.0                 1 TB HDD            i5 5th Gen
# 464      Apple      4.0                      NaN            i5 5th Gen
# 580       Asus      4.0               500 GB HDD      i7 Processor4 GB
# 289         HP      8.0                 1 TB HDD            i5 7th Gen
# 394         HP      4.0               500 GB HDD                   NaN
# 759       Acer      8.0                 1 TB HDD            i5 8th Gen
# 414       Dell      4.0                 1 TB HDD            i5 5th Gen
# 511         HP      4.0                 1 TB HDD            i5 5th Gen
# 616       Asus      4.0               500 GB HDD            i5 4th Gen
# 764       Asus      4.0               256 GB SSD          Dual Core E2
# 736     Lenovo      4.0               128 GB SSD                   NaN
# ...

# %%
L1.sort_values(by='Rating',ascending=False)
# Out:
#         Brands  Ram[GB]                  Storage    Processor  \
# 400       Acer      8.0                 2 TB HDD   i7 6th Gen
# 696        MSI     16.0      1 TB HDD 512 GB SSD   i7 8th Gen
# 669       Acer      8.0      2 TB HDD 256 GB SSD   i7 9th Gen
# 429       Dell      4.0                 1 TB HDD   i5 6th Gen
# 173        MSI     16.0      1 TB HDD 128 GB SSD   i7 7th Gen
# 796       Asus      4.0               256 GB SSD          NaN
# 150       Dell      8.0               256 GB SSD   i7 8th Gen
# 695        MSI      8.0      1 TB HDD 128 GB SSD   i7 9th Gen
# 301        MSI     16.0      1 TB HDD 128 GB SSD   i7 7th Gen
# 89        Acer     16.0      1 TB HDD 256 GB SSD   i7 9th Gen
# 131  Alienware     16.0      1 TB HDD 512 GB SSD   i7 6th Gen
# 284        MSI     16.0      1 TB HDD 256 GB SSD   i7 7th Gen
# 726     Lenovo      8.0               512 GB SSD   i5 8th Gen
# 496      Apple     16.0               256 GB SSD   i7 8th Gen
# ...

# %% [markdown]
# #### Observation:-
# - The Laptops have been arranged in the order of the highest to lowest rated laptops
# - In which Apple Mac book has been rated 5.0 by 12 members and 1 review was given so this is considered best laptop in Apple and by the use or product rating.
# - The least rating is Lenovo and Dell in which rating was 1.0 and 1.6 given by 1 member and 1 review provided,12 members and 1 review respectively.

# %% [markdown]
# ### Treating missing values

# %%
L1['Operating system'].replace(to_replace='512',value='Mac',inplace=True)
L1
# Out:
# C:\Users\Yamini\Anaconda3\lib\site-packages\pandas\core\generic.py:6586: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
#         Brands  Ram[GB]              Storage     Processor  \
# 0         Acer      8.0  1 TB HDD 128 GB SSD    i5 8th Gen
# 1          MSI     16.0           512 GB SSD    i7 8th Gen
# 2         Asus      8.0  1 TB HDD 128 GB SSD    i7 7th Gen
# 3         Asus      8.0  1 TB HDD 128 GB SSD    i5 8th Gen
# 4          MSI     16.0  1 TB HDD 512 GB SSD    i7 8th Gen
# 5         Asus      8.0  1 TB HDD 128 GB SSD    i7 7th Gen
# 6         Asus      8.0             1 TB HDD    i7 7th Gen
# 7         Asus      8.0  1 TB HDD 256 GB SSD    i7 7th Gen
# 8         Acer      8.0  1 TB HDD 128 GB SSD    i5 7th Gen
# ...

# %%
L1.sort_values(by='Disc_price',ascending=False)
# Out:
#         Brands  Ram[GB]                Storage             Processor  \
# 780        MSI     32.0      1 TB HDD 1 TB SSD            i9 9th Gen
# 210        MSI     32.0    1 TB HDD 512 GB SSD            i7 8th Gen
# 683         HP     16.0               1 TB SSD            i7 8th Gen
# 697       Asus     32.0               1 TB SSD            i7 9th Gen
# 506         HP     16.0               2 TB SSD            i9 9th Gen
# 197        MSI     32.0               1 TB SSD            i7 9th Gen
# 470         HP     16.0               1 TB SSD            i7 9th Gen
# 757      Apple     16.0             512 GB SSD            i7 7th Gen
# 809        MSI     16.0               1 TB SSD            i7 9th Gen
# 561      Apple     16.0             512 GB SSD            i7 7th Gen
# 765       Asus     32.0               1 TB SSD            i7 9th Gen
# 284        MSI     16.0    1 TB HDD 256 GB SSD            i7 7th Gen
# 475         HP     16.0             512 GB SSD            i7 9th Gen
# ...

# %% [markdown]
# #### Observation:-
# - The highest laptop cost is Rs.3,99,990 which is in the brand MSI in both processors i7 and i9.
# - The least laptop cost is Rs.11450 which is Iball laptop.

# %%
L1['Brands'].value_counts()
# Out:
# HP           239
# Asus         187
# Dell         100
# Acer          96
# Lenovo        92
# MSI           47
# Apple         20
# Avita         12
# Microsoft      9
# Alienware      5
# Sony           2
# Iball          1
# Nexstgo        1
# i-Life         1
# Name: Brands, dtype: int64

# %% [markdown]
# - The laptops available for analysis in different brands have been obtained from the dataframe

# %%
L1[L1['Brands']=='Acer'].sort_values(by='Disc_price',ascending=False)
# Out:
#     Brands  Ram[GB]                Storage             Processor  \
# 671   Acer     16.0    2 TB HDD 256 GB SSD            i7 9th Gen
# 656   Acer     16.0    1 TB HDD 256 GB SSD            i7 8th Gen
# 89    Acer     16.0    1 TB HDD 256 GB SSD            i7 9th Gen
# 669   Acer      8.0    2 TB HDD 256 GB SSD            i7 9th Gen
# 8     Acer      8.0    1 TB HDD 128 GB SSD            i5 7th Gen
# 664   Acer     16.0    1 TB HDD 128 GB SSD            i5 8th Gen
# 607   Acer     12.0               1 TB HDD            i7 4th Gen
# 501   Acer     16.0    1 TB HDD 128 GB SSD            i5 7th Gen
# 33    Acer     16.0    1 TB HDD 256 GB SSD            i7 9th Gen
# 444   Acer     12.0               1 TB HDD            i7 4th Gen
# 186   Acer      8.0    1 TB HDD 256 GB SSD            i7 9th Gen
# 565   Acer      8.0               1 TB HDD            i5 8th Gen
# 78    Acer      8.0             512 GB SSD            i5 8th Gen
# ...

# %%
type('Storage')
# Out:
# str

# %%
L1.shape
# Out:
# (812, 10)

# %% [markdown]
# ### Treating data
# #### 1.Apple Brand(OS)

# %%
L1[L1['Brands']=='Apple'].sort_values(by='Disc_price',ascending=False)
# Out:
#     Brands  Ram[GB]                Storage          Processor  \
# 757  Apple     16.0             512 GB SSD         i7 7th Gen
# 561  Apple     16.0             512 GB SSD         i7 7th Gen
# 369  Apple     16.0  512 GB HDD 512 GB SSD         i7 5th Gen
# 496  Apple     16.0             256 GB SSD         i7 8th Gen
# 775  Apple     16.0             512 GB SSD  i7 Processor16 GB
# 795  Apple      8.0             512 GB SSD         i5 8th Gen
# 114  Apple      8.0             256 GB SSD         i5 8th Gen
# 280  Apple      8.0             512 GB SSD         i5 7th Gen
# 417  Apple      8.0             512 GB SSD         i5 5th Gen
# 745  Apple      8.0             128 GB SSD         i5 8th Gen
# 743  Apple      8.0             256 GB SSD                NaN
# 761  Apple      8.0             128 GB SSD         i5 7th Gen
# 221  Apple      8.0             256 GB SSD         i5 8th Gen
# 255  Apple      8.0             256 GB SSD                NaN
# ...

# %%
Apple = L1[L1['Brands']=='Apple'].sort_values(by='Disc_price',ascending=False)
Apple
# Out:
#     Brands  Ram[GB]                Storage          Processor  \
# 757  Apple     16.0             512 GB SSD         i7 7th Gen
# 561  Apple     16.0             512 GB SSD         i7 7th Gen
# 369  Apple     16.0  512 GB HDD 512 GB SSD         i7 5th Gen
# 496  Apple     16.0             256 GB SSD         i7 8th Gen
# 775  Apple     16.0             512 GB SSD  i7 Processor16 GB
# 795  Apple      8.0             512 GB SSD         i5 8th Gen
# 114  Apple      8.0             256 GB SSD         i5 8th Gen
# 280  Apple      8.0             512 GB SSD         i5 7th Gen
# 417  Apple      8.0             512 GB SSD         i5 5th Gen
# 745  Apple      8.0             128 GB SSD         i5 8th Gen
# 743  Apple      8.0             256 GB SSD                NaN
# 761  Apple      8.0             128 GB SSD         i5 7th Gen
# 221  Apple      8.0             256 GB SSD         i5 8th Gen
# 255  Apple      8.0             256 GB SSD                NaN
# ...

# %%
Apple['Operating system'].fillna('Mac',inplace=True)

# %%
Apple['Operating system'].replace(to_replace='256',value='Mac',inplace=True)

# %%
Apple['Operating system'].replace(to_replace='OS',value='Mac',inplace=True)

# %%
Apple.isnull().sum()
# Out:
# Brands              0
# Ram[GB]             0
# Storage             2
# Processor           3
# Model               0
# Rating              5
# Disc_price          0
# No of Ratings       5
# No of Reviews       5
# Operating system    0
# dtype: int64

# %%
Apple.tail()
# Out:
#     Brands  Ram[GB]                Storage         Processor  \
# 409  Apple      8.0  512 GB HDD 256 GB SSD               NaN
# 464  Apple      4.0                    NaN        i5 5th Gen
# 484  Apple      4.0             128 GB SSD        i5 5th Gen
# 383  Apple      4.0                    NaN  i5 Processor4 GB
# 17   Apple      8.0             128 GB SSD        i5 5th Gen
#
#                                                  Model  Rating  Disc_price  \
# 409                                            MacBook     4.6       93989
# 464          MacBook Air 2015 MJVP2HN/A (Ultrabook ) (     2.0       79900
# 484                                        MacBook Air     4.1       65900
# 383  MD760HN/B MacBook Air (Ci5/ 4GB/ 128GB Flash/ ...     4.6       60693
# 17                                         MacBook Air     4.7       54990
#
#      No of Ratings  No of Reviews Operating system
# 409           12.0            2.0              Mac
# ...

# %%
L1[L1['Brands']=='Apple']=Apple

# %%
Apple
# Out:
#     Brands  Ram[GB]                Storage          Processor  \
# 757  Apple     16.0             512 GB SSD         i7 7th Gen
# 561  Apple     16.0             512 GB SSD         i7 7th Gen
# 369  Apple     16.0  512 GB HDD 512 GB SSD         i7 5th Gen
# 496  Apple     16.0             256 GB SSD         i7 8th Gen
# 775  Apple     16.0             512 GB SSD  i7 Processor16 GB
# 795  Apple      8.0             512 GB SSD         i5 8th Gen
# 114  Apple      8.0             256 GB SSD         i5 8th Gen
# 280  Apple      8.0             512 GB SSD         i5 7th Gen
# 417  Apple      8.0             512 GB SSD         i5 5th Gen
# 745  Apple      8.0             128 GB SSD         i5 8th Gen
# 743  Apple      8.0             256 GB SSD                NaN
# 761  Apple      8.0             128 GB SSD         i5 7th Gen
# 221  Apple      8.0             256 GB SSD         i5 8th Gen
# 255  Apple      8.0             256 GB SSD                NaN
# ...

# %% [markdown]
# ##### Observation:-
# - The missing values are treated in OS by replacing it with Mac OS as it is the only OS used in Apple
# - In Apple Laptops the highest cost is Rs.2,29,990 and the least cost is Rs.20868
# - The highest rated laptop is Apple Macbook Pro i7 8th Gen
# - The Apple Laptops ratings are in the range of 2.0-5

# %% [markdown]
# ### 2.Microsoft

# %%
Microsoft = L1[L1['Brands']=='Microsoft'].sort_values(by='Disc_price',ascending=False)
Microsoft
# Out:
#         Brands  Ram[GB]     Storage   Processor  \
# 507  Microsoft      8.0  256 GB SSD  i5 8th Gen
# 719  Microsoft      8.0  256 GB SSD  i5 8th Gen
# 767  Microsoft      8.0  128 GB SSD  i5 7th Gen
# 787  Microsoft      8.0  128 GB SSD  i5 7th Gen
# 786  Microsoft      4.0  128 GB SSD  i5 7th Gen
# 789  Microsoft      8.0  128 GB SSD  i5 8th Gen
# 673  Microsoft      8.0  128 GB SSD  i5 8th Gen
# 785  Microsoft      8.0  128 GB SSD  i5 8th Gen
# 788  Microsoft      4.0         NaN         NaN
#
#                                                  Model  Rating  Disc_price  \
# 507                                   Surface Laptop 2     NaN      116990
# 719                                      Surface Pro 6     NaN      107990
# 767                                            Surface     4.4       81990
# 787                                            Surface     4.4       81990
# 786                                        Surface Pro     4.5       79999
# ...

# %%
L1[L1['Brands']=='Microsoft']=Microsoft

# %% [markdown]
# ### 3.Sony

# %%
Sony = L1[L1['Brands']=='Sony'].sort_values(by='Disc_price',ascending=False)
Sony
# Out:
#     Brands  Ram[GB]     Storage         Processor  \
# 164   Sony      4.0  750 GB HDD        i5 3rd Gen
# 156   Sony      4.0         NaN  i7 Processor4 GB
#
#                                                  Model  Rating  Disc_price  \
# 164                                                        3.7       69990
# 156  VAIO SVE1413YPNB Laptop (3rd Gen Ci7/ 4GB/ 500...     3.8       65990
#
#      No of Ratings  No of Reviews Operating system
# 164           26.0            6.0    Windows 8 Pro
# 156           42.0           12.0              NaN

# %%
Sony['Operating system'].fillna('Windows 8 Pro',inplace=True)

# %%
Sony
# Out:
#     Brands  Ram[GB]     Storage         Processor  \
# 164   Sony      4.0  750 GB HDD        i5 3rd Gen
# 156   Sony      4.0         NaN  i7 Processor4 GB
#
#                                                  Model  Rating  Disc_price  \
# 164                                                        3.7       69990
# 156  VAIO SVE1413YPNB Laptop (3rd Gen Ci7/ 4GB/ 500...     3.8       65990
#
#      No of Ratings  No of Reviews Operating system
# 164           26.0            6.0    Windows 8 Pro
# 156           42.0           12.0    Windows 8 Pro

# %%
L1[L1['Brands']=='Sony']=Sony

# %% [markdown]
# ### 4.Avita

# %%
Avita = L1[L1['Brands']=='Avita'].sort_values(by='Disc_price',ascending=False)
Avita
# Out:
#     Brands  Ram[GB]     Storage             Processor               Model  \
# 721  Avita      8.0  128 GB SSD            i3 8th Gen               Liber
# 739  Avita      8.0  128 GB SSD            i3 8th Gen               Liber
# 665  Avita      8.0  256 GB SSD            i5 7th Gen               Liber
# 808  Avita      8.0  256 GB SSD            i5 7th Gen               Liber
# 279  Avita      8.0  256 GB SSD            i5 8th Gen               Liber
# 724  Avita      8.0  128 GB SSD            i3 8th Gen               Liber
# 40   Avita      8.0  256 GB SSD            i5 8th Gen               Liber
# 54   Avita      8.0  256 GB SSD            i5 8th Gen               Liber
# 63   Avita      8.0  256 GB SSD            i5 8th Gen               Liber
# 97   Avita      8.0  256 GB SSD            i5 8th Gen               Liber
# 108  Avita      8.0  256 GB SSD            i5 8th Gen               Liber
# 105  Avita      4.0         NaN  Dual Core Processor4  Magus Celeron Dual
#
# ...

# %%
L1[L1['Brands']=='Avita']=Avita

# %% [markdown]
# ### 5.MSI

# %%
MSI = L1[L1['Brands']=='MSI'].sort_values(by='Disc_price',ascending=False)
MSI
# Out:
#     Brands  Ram[GB]              Storage    Processor  \
# 780    MSI     32.0    1 TB HDD 1 TB SSD   i9 9th Gen
# 210    MSI     32.0  1 TB HDD 512 GB SSD   i7 8th Gen
# 197    MSI     32.0             1 TB SSD   i7 9th Gen
# 809    MSI     16.0             1 TB SSD   i7 9th Gen
# 284    MSI     16.0  1 TB HDD 256 GB SSD   i7 7th Gen
# 696    MSI     16.0  1 TB HDD 512 GB SSD   i7 8th Gen
# 18     MSI     16.0  1 TB HDD 512 GB SSD   i7 9th Gen
# 686    MSI     16.0           512 GB SSD   i7 8th Gen
# 254    MSI     16.0           512 GB SSD   i7 8th Gen
# 689    MSI     16.0  1 TB HDD 256 GB SSD   i7 7th Gen
# 711    MSI     16.0           512 GB SSD   i7 9th Gen
# 4      MSI     16.0  1 TB HDD 512 GB SSD   i7 8th Gen
# 200    MSI     32.0             1 TB SSD   i7 9th Gen
# 690    MSI     16.0  1 TB HDD 256 GB SSD   i7 8th Gen
# 679    MSI     16.0           512 GB SSD   i7 8th Gen
# 1      MSI     16.0           512 GB SSD   i7 8th Gen
# ...

# %%
MSI['Operating system'].fillna('Windows 10',inplace=True)

# %%
MSI
# Out:
#     Brands  Ram[GB]              Storage    Processor  \
# 780    MSI     32.0    1 TB HDD 1 TB SSD   i9 9th Gen
# 210    MSI     32.0  1 TB HDD 512 GB SSD   i7 8th Gen
# 197    MSI     32.0             1 TB SSD   i7 9th Gen
# 809    MSI     16.0             1 TB SSD   i7 9th Gen
# 284    MSI     16.0  1 TB HDD 256 GB SSD   i7 7th Gen
# 696    MSI     16.0  1 TB HDD 512 GB SSD   i7 8th Gen
# 18     MSI     16.0  1 TB HDD 512 GB SSD   i7 9th Gen
# 686    MSI     16.0           512 GB SSD   i7 8th Gen
# 254    MSI     16.0           512 GB SSD   i7 8th Gen
# 689    MSI     16.0  1 TB HDD 256 GB SSD   i7 7th Gen
# 711    MSI     16.0           512 GB SSD   i7 9th Gen
# 4      MSI     16.0  1 TB HDD 512 GB SSD   i7 8th Gen
# 200    MSI     32.0             1 TB SSD   i7 9th Gen
# 690    MSI     16.0  1 TB HDD 256 GB SSD   i7 8th Gen
# 679    MSI     16.0           512 GB SSD   i7 8th Gen
# 1      MSI     16.0           512 GB SSD   i7 8th Gen
# ...

# %%
L1[L1['Brands']=='MSI']=MSI

# %% [markdown]
# ### 6.Dell

# %%
Dell = L1[L1['Brands']=='Dell'].sort_values(by='Disc_price',ascending=False)
Dell
# Out:
#     Brands  Ram[GB]                Storage             Processor  \
# 706   Dell     16.0             512 GB SSD            i7 9th Gen
# 150   Dell      8.0             256 GB SSD            i7 8th Gen
# 704   Dell     16.0             512 GB SSD            i7 9th Gen
# 610   Dell     16.0    1 TB HDD 256 GB SSD            i7 7th Gen
# 699   Dell     16.0    1 TB HDD 256 GB SSD            i7 7th Gen
# 680   Dell      8.0    1 TB HDD 512 GB SSD            i7 9th Gen
# 453   Dell     16.0               2 TB HDD            i7 7th Gen
# 41    Dell      8.0             256 GB SSD            i5 8th Gen
# 52    Dell      8.0    1 TB HDD 512 GB SSD            i7 8th Gen
# 175   Dell      8.0    2 TB HDD 128 GB SSD            i7 8th Gen
# 223   Dell      8.0               1 TB HDD            i7 7th Gen
# 474   Dell      8.0               1 TB HDD            i7 7th Gen
# 407   Dell      8.0               1 TB HDD            i5 7th Gen
# ...

# %%
Dell['Operating system'].fillna('Windows 10 Home',inplace=True)

# %%
Dell.isnull().sum()
# Out:
# Brands               0
# Ram[GB]              0
# Storage              6
# Processor           13
# Model                0
# Rating               9
# Disc_price           0
# No of Ratings        9
# No of Reviews        9
# Operating system     0
# dtype: int64

# %%
L1[L1['Brands']=='Dell']=Dell

# %% [markdown]
# ### 7.HP(Hewlett Packard)

# %%
HP = L1[L1['Brands']=='HP'].sort_values(by='Disc_price',ascending=False)
HP
# Out:
#     Brands  Ram[GB]                  Storage             Processor  \
# 683     HP     16.0                 1 TB SSD            i7 8th Gen
# 506     HP     16.0                 2 TB SSD            i9 9th Gen
# 470     HP     16.0                 1 TB SSD            i7 9th Gen
# 475     HP     16.0               512 GB SSD            i7 9th Gen
# 536     HP     16.0               512 GB SSD            i7 8th Gen
# 703     HP     16.0               512 GB SSD            i7 8th Gen
# 529     HP     16.0      1 TB HDD 256 GB SSD            i7 8th Gen
# 445     HP     16.0      1 TB HDD 512 GB SSD            i7 9th Gen
# 209     HP     16.0      1 TB HDD 128 GB SSD            i7 7th Gen
# 455     HP     16.0      1 TB HDD 128 GB SSD            i7 7th Gen
# 493     HP      8.0               512 GB SSD            i7 6th Gen
# 783     HP      8.0      1 TB HDD 128 GB SSD            i5 7th Gen
# 517     HP     16.0      1 TB HDD 128 GB SSD            i7 7th Gen
# ...

# %%
HP['Operating system'].fillna('Windows 10 Home',inplace=True)

# %%
HP.isnull().sum()
# Out:
# Brands               0
# Ram[GB]              0
# Storage              6
# Processor           24
# Model                0
# Rating              28
# Disc_price           0
# No of Ratings       28
# No of Reviews       28
# Operating system     0
# dtype: int64

# %%
L1[L1['Brands']=='HP']=HP

# %% [markdown]
# ### 8.Lenovo

# %%
Lenovo = L1[L1['Brands']=='Lenovo'].sort_values(by='Disc_price',ascending=False)
Lenovo
# Out:
#      Brands  Ram[GB]              Storage             Processor  \
# 179  Lenovo     16.0    1 TB HDD 8 GB SSD            i7 4th Gen
# 323  Lenovo     16.0  1 TB HDD 128 GB SSD            i7 6th Gen
# 725  Lenovo     16.0  1 TB HDD 128 GB SSD            i7 7th Gen
# 781  Lenovo      8.0           512 GB SSD            i5 8th Gen
# 314  Lenovo      8.0           256 GB SSD            i7 7th Gen
# 726  Lenovo      8.0           512 GB SSD            i5 8th Gen
# 763  Lenovo      8.0             1 TB SSD            i3 8th Gen
# 655  Lenovo      8.0    1 TB HDD 8 GB SSD            i7 4th Gen
# 207  Lenovo      8.0           512 GB SSD            i5 8th Gen
# 180  Lenovo      8.0           256 GB SSD            i5 7th Gen
# 264  Lenovo      8.0  1 TB HDD 128 GB SSD            i7 9th Gen
# 137  Lenovo      8.0             1 TB HDD            i7 5th Gen
# 601  Lenovo      8.0             1 TB HDD            i7 5th Gen
# 810  Lenovo      8.0             1 TB HDD            i5 7th Gen
# ...

# %%
Lenovo['Operating system'].fillna('Windows 10 Home',inplace=True)

# %%
Lenovo['Operating system'].isnull().sum()
# Out:
# 0

# %%
Lenovo.loc[436:437]
# Out:
#      Brands  Ram[GB]     Storage             Processor  \
# 436  Lenovo      4.0         NaN                   NaN
# 206  Lenovo      4.0  500 GB HDD                   NaN
# 811  Lenovo      4.0    1 TB HDD                   NaN
# 717  Lenovo      4.0  500 GB HDD  Dual Core Processor4
# 57   Lenovo      4.0    1 TB HDD            i3 7th Gen
# 34   Lenovo      4.0    1 TB HDD            i3 7th Gen
# 437  Lenovo      2.0  500 GB HDD                   NaN
#
#                          Model  Rating  Disc_price  No of Ratings  \
# 436  G50-45 Notebook (APU Quad     3.9       24646          142.0
# 206   IdeaPad 100 Pentium Quad     3.9       23990           71.0
# 811       IdeaPad Pentium Quad     4.0       23987          357.0
# 717   Ideapad 330 Celeron Dual     4.1       22990          160.0
# 57                 Ideapad 330     4.0       22990           61.0
# 34                 Ideapad 130     4.1       22990         4248.0
# ...

# %%
L1[L1['Brands']=='Lenovo']=Lenovo

# %% [markdown]
# ### 9. Acer

# %%
Acer = L1[L1['Brands']=='Acer'].sort_values(by='Disc_price',ascending=False)
Acer
# Out:
#     Brands  Ram[GB]                Storage             Processor  \
# 671   Acer     16.0    2 TB HDD 256 GB SSD            i7 9th Gen
# 656   Acer     16.0    1 TB HDD 256 GB SSD            i7 8th Gen
# 89    Acer     16.0    1 TB HDD 256 GB SSD            i7 9th Gen
# 669   Acer      8.0    2 TB HDD 256 GB SSD            i7 9th Gen
# 8     Acer      8.0    1 TB HDD 128 GB SSD            i5 7th Gen
# 664   Acer     16.0    1 TB HDD 128 GB SSD            i5 8th Gen
# 607   Acer     12.0               1 TB HDD            i7 4th Gen
# 501   Acer     16.0    1 TB HDD 128 GB SSD            i5 7th Gen
# 33    Acer     16.0    1 TB HDD 256 GB SSD            i7 9th Gen
# 444   Acer     12.0               1 TB HDD            i7 4th Gen
# 186   Acer      8.0    1 TB HDD 256 GB SSD            i7 9th Gen
# 565   Acer      8.0               1 TB HDD            i5 8th Gen
# 78    Acer      8.0             512 GB SSD            i5 8th Gen
# ...

# %%
Acer['Operating system'].fillna('Windows 10 Home',inplace = True)

# %%
Acer['Operating system'].isnull().sum()
# Out:
# 0

# %%
Acer['Operating system'].replace(to_replace='32',value='Windows 10 Home',inplace=True)

# %%
Acer
# Out:
#     Brands  Ram[GB]                Storage             Processor  \
# 671   Acer     16.0    2 TB HDD 256 GB SSD            i7 9th Gen
# 656   Acer     16.0    1 TB HDD 256 GB SSD            i7 8th Gen
# 89    Acer     16.0    1 TB HDD 256 GB SSD            i7 9th Gen
# 669   Acer      8.0    2 TB HDD 256 GB SSD            i7 9th Gen
# 8     Acer      8.0    1 TB HDD 128 GB SSD            i5 7th Gen
# 664   Acer     16.0    1 TB HDD 128 GB SSD            i5 8th Gen
# 607   Acer     12.0               1 TB HDD            i7 4th Gen
# 501   Acer     16.0    1 TB HDD 128 GB SSD            i5 7th Gen
# 33    Acer     16.0    1 TB HDD 256 GB SSD            i7 9th Gen
# 444   Acer     12.0               1 TB HDD            i7 4th Gen
# 186   Acer      8.0    1 TB HDD 256 GB SSD            i7 9th Gen
# 565   Acer      8.0               1 TB HDD            i5 8th Gen
# 78    Acer      8.0             512 GB SSD            i5 8th Gen
# ...

# %%
L1[L1['Brands']=='Acer'] = Acer

# %% [markdown]
# ### 10. Asus

# %%
Asus = L1[L1['Brands']=='Asus'].sort_values(by='Disc_price',ascending=False)
Asus
# Out:
#     Brands  Ram[GB]              Storage             Processor  \
# 697   Asus     32.0             1 TB SSD            i7 9th Gen
# 765   Asus     32.0             1 TB SSD            i7 9th Gen
# 779   Asus     16.0  1 TB HDD 256 GB SSD            i7 8th Gen
# 533   Asus     16.0  1 TB HDD 256 GB SSD            i7 8th Gen
# 283   Asus     16.0             1 TB SSD            i7 9th Gen
# 509   Asus     16.0  1 TB HDD 256 GB SSD            i7 7th Gen
# 7     Asus      8.0  1 TB HDD 256 GB SSD            i7 7th Gen
# 694   Asus     16.0  1 TB HDD 256 GB SSD            i7 9th Gen
# 540   Asus     16.0  1 TB HDD 256 GB SSD            i7 8th Gen
# 6     Asus      8.0             1 TB HDD            i7 7th Gen
# 489   Asus      8.0           512 GB SSD            i7 8th Gen
# 586   Asus      8.0           512 GB SSD            i7 8th Gen
# 630   Asus     16.0  1 TB HDD 256 GB SSD                   NaN
# 449   Asus      8.0  1 TB HDD 128 GB SSD            i7 7th Gen
# ...

# %%
Asus['Operating system'].fillna('Windows 10 Home',inplace = True)

# %%
Asus.isnull().sum()
# Out:
# Brands               0
# Ram[GB]              0
# Storage              8
# Processor           22
# Model                0
# Rating              21
# Disc_price           0
# No of Ratings       21
# No of Reviews       21
# Operating system     0
# dtype: int64

# %%
Asus['Operating system'].replace(to_replace='128',value='Windows 10 Home',inplace=True)

# %%
Asus['Operating system'].replace(to_replace='Endless',value='Windows 10 Home',inplace=True)

# %%
#Asus[Asus['Operating system']=='128']
Asus.loc[434:]
# Out:
#     Brands  Ram[GB]              Storage             Processor  \
# 434   Asus      8.0  1 TB HDD 128 GB SSD            i7 7th Gen
# 119   Asus      8.0           512 GB SSD            i5 8th Gen
# 11    Asus      8.0  1 TB HDD 128 GB SSD            i5 8th Gen
# 319   Asus      8.0           256 GB SSD            i5 8th Gen
# 531   Asus      8.0           512 GB SSD            i5 8th Gen
# 234   Asus      8.0  1 TB HDD 256 GB SSD            i7 8th Gen
# 415   Asus      8.0           512 GB SSD            i7 8th Gen
# 344   Asus      8.0             1 TB HDD            i7 7th Gen
# 479   Asus      8.0           256 GB SSD            i5 8th Gen
# 13    Asus      8.0             1 TB HDD            i7 7th Gen
# 709   Asus      8.0  1 TB HDD 128 GB SSD            i5 8th Gen
# 3     Asus      8.0  1 TB HDD 128 GB SSD            i5 8th Gen
# 727   Asus      8.0           512 GB SSD            i7 8th Gen
# 149   Asus      8.0  1 TB HDD 128 GB SSD            i5 8th Gen
# ...

# %%
Asus.loc[74]
# Out:
# Brands                         Asus
# Ram[GB]                           4
# Storage                    1 TB HDD
# Processor                i3 7th Gen
# Model                      X Series
# Rating                          4.1
# Disc_price                    22990
# No of Ratings                  1044
# No of Reviews                   123
# Operating system    Windows 10 Home
# Name: 74, dtype: object

# %%
L1[L1['Brands']=='Asus'] = Asus

# %%
Asus.loc[74]
# Out:
# Brands                         Asus
# Ram[GB]                           4
# Storage                    1 TB HDD
# Processor                i3 7th Gen
# Model                      X Series
# Rating                          4.1
# Disc_price                    22990
# No of Ratings                  1044
# No of Reviews                   123
# Operating system    Windows 10 Home
# Name: 74, dtype: object

# %%
L1.loc[74]
# Out:
# Brands                         Asus
# Ram[GB]                           4
# Storage                    1 TB HDD
# Processor                i3 7th Gen
# Model                      X Series
# Rating                          4.1
# Disc_price                    22990
# No of Ratings                  1044
# No of Reviews                   123
# Operating system    Windows 10 Home
# Name: 74, dtype: object

# %%
L1.isnull().sum()
# Out:
# Brands                0
# Ram[GB]               0
# Storage              32
# Processor            97
# Model                 0
# Rating              105
# Disc_price            0
# No of Ratings       105
# No of Reviews       105
# Operating system      0
# dtype: int64

# %%
L1.notnull().sum()
# Out:
# Brands              812
# Ram[GB]             812
# Storage             780
# Processor           715
# Model               812
# Rating              707
# Disc_price          812
# No of Ratings       707
# No of Reviews       707
# Operating system    812
# dtype: int64

# %%
L1[L1.isnull().sum(axis=1)>3]
# Out:
#      Brands  Ram[GB]              Storage     Processor  \
# 101      HP      8.0  1 TB HDD 256 GB SSD           NaN
# 117      HP      8.0  1 TB HDD 128 GB SSD           NaN
# 235      HP      4.0           128 GB SSD           NaN
# 255   Apple      8.0           256 GB SSD           NaN
# 405  i-Life      2.0                  NaN           NaN
# 544    Asus      4.0           128 GB SSD           NaN
# 573    Dell      4.0                  NaN  Dual Core E1
# 574    Asus      2.0           500 GB HDD           NaN
# 644    Dell      4.0             1 TB HDD           NaN
# 654    Asus      8.0           512 GB SSD           NaN
# 743   Apple      8.0           256 GB SSD           NaN
# 804    Dell      4.0             1 TB HDD           NaN
# 805    Asus      8.0           512 GB SSD           NaN
#
#                                 Model  Rating  Disc_price  No of Ratings  \
# 101             Pavilion Ryzen 5 Quad     NaN       55940            NaN
# ...

# %%
L1.drop(L1[L1.isnull().sum(axis=1)>3].index,inplace=True)

# %%
L1.isnull().sum()
# Out:
# Brands               0
# Ram[GB]              0
# Storage             30
# Processor           85
# Model                0
# Rating              92
# Disc_price           0
# No of Ratings       92
# No of Reviews       92
# Operating system     0
# dtype: int64

# %%
L1.dropna(subset=['Processor'],inplace=True)

# %%
L1['Rating'].fillna('0',inplace=True)

# %%
L1.isnull().sum()
# Out:
# Brands               0
# Ram[GB]              0
# Storage             10
# Processor            0
# Model                0
# Rating               0
# Disc_price           0
# No of Ratings       92
# No of Reviews       92
# Operating system     0
# dtype: int64

# %%
L1.dropna(subset=['Storage'],inplace=True)

# %%
L1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 704 entries, 0 to 810
# Data columns (total 10 columns):
# Brands              704 non-null object
# Ram[GB]             704 non-null float64
# Storage             704 non-null object
# Processor           704 non-null object
# Model               704 non-null object
# Rating              704 non-null object
# Disc_price          704 non-null int64
# No of Ratings       612 non-null float64
# No of Reviews       612 non-null float64
# Operating system    704 non-null object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 60.5+ KB

# %%
L1['No of Ratings'].fillna('0',inplace=True)

# %%
L1['No of Reviews'].fillna('0',inplace=True)

# %%
L1.isnull().sum()
# Out:
# Brands              0
# Ram[GB]             0
# Storage             0
# Processor           0
# Model               0
# Rating              0
# Disc_price          0
# No of Ratings       0
# No of Reviews       0
# Operating system    0
# dtype: int64

# %%
L1.shape
# Out:
# (704, 10)

# %%
L1
# Out:
#         Brands  Ram[GB]              Storage     Processor  \
# 0         Acer      8.0  1 TB HDD 128 GB SSD    i5 8th Gen
# 1          MSI     16.0           512 GB SSD    i7 8th Gen
# 2         Asus      8.0  1 TB HDD 128 GB SSD    i7 7th Gen
# 3         Asus      8.0  1 TB HDD 128 GB SSD    i5 8th Gen
# 4          MSI     16.0  1 TB HDD 512 GB SSD    i7 8th Gen
# 5         Asus      8.0  1 TB HDD 128 GB SSD    i7 7th Gen
# 6         Asus      8.0             1 TB HDD    i7 7th Gen
# 7         Asus      8.0  1 TB HDD 256 GB SSD    i7 7th Gen
# 8         Acer      8.0  1 TB HDD 128 GB SSD    i5 7th Gen
# 9          MSI      8.0  1 TB HDD 128 GB SSD    i7 7th Gen
# 10        Acer      8.0  1 TB HDD 128 GB SSD    i5 7th Gen
# 11        Asus      8.0  1 TB HDD 128 GB SSD    i5 8th Gen
# 12         MSI     16.0  1 TB HDD 128 GB SSD    i7 8th Gen
# 13        Asus      8.0             1 TB HDD    i7 7th Gen
# 14      Lenovo      8.0  1 TB HDD 128 GB SSD    i5 7th Gen
# ...

# %%
L1.reset_index(inplace=True)

# %%
L1
# Out:
#      index     Brands  Ram[GB]              Storage     Processor  \
# 0        0       Acer      8.0  1 TB HDD 128 GB SSD    i5 8th Gen
# 1        1        MSI     16.0           512 GB SSD    i7 8th Gen
# 2        2       Asus      8.0  1 TB HDD 128 GB SSD    i7 7th Gen
# 3        3       Asus      8.0  1 TB HDD 128 GB SSD    i5 8th Gen
# 4        4        MSI     16.0  1 TB HDD 512 GB SSD    i7 8th Gen
# 5        5       Asus      8.0  1 TB HDD 128 GB SSD    i7 7th Gen
# 6        6       Asus      8.0             1 TB HDD    i7 7th Gen
# 7        7       Asus      8.0  1 TB HDD 256 GB SSD    i7 7th Gen
# 8        8       Acer      8.0  1 TB HDD 128 GB SSD    i5 7th Gen
# 9        9        MSI      8.0  1 TB HDD 128 GB SSD    i7 7th Gen
# 10      10       Acer      8.0  1 TB HDD 128 GB SSD    i5 7th Gen
# 11      11       Asus      8.0  1 TB HDD 128 GB SSD    i5 8th Gen
# 12      12        MSI     16.0  1 TB HDD 128 GB SSD    i7 8th Gen
# ...

# %%
L1.drop(columns='index',inplace=True)

# %%
L1.to_csv('Cleaned data csv')
