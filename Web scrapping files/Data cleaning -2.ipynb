# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import numpy as np
import pandas as pd

# %%
L2 = pd.read_csv("Cleaned data csv")
L2
# Out:
#      Unnamed: 0     Brands  Ram[GB]              Storage     Processor  \
# 0             0       Acer      8.0  1 TB HDD 128 GB SSD    i5 8th Gen
# 1             1        MSI     16.0           512 GB SSD    i7 8th Gen
# 2             2       Asus      8.0  1 TB HDD 128 GB SSD    i7 7th Gen
# 3             3       Asus      8.0  1 TB HDD 128 GB SSD    i5 8th Gen
# 4             4        MSI     16.0  1 TB HDD 512 GB SSD    i7 8th Gen
# 5             5       Asus      8.0  1 TB HDD 128 GB SSD    i7 7th Gen
# 6             6       Asus      8.0             1 TB HDD    i7 7th Gen
# 7             7       Asus      8.0  1 TB HDD 256 GB SSD    i7 7th Gen
# 8             8       Acer      8.0  1 TB HDD 128 GB SSD    i5 7th Gen
# 9             9        MSI      8.0  1 TB HDD 128 GB SSD    i7 7th Gen
# 10           10       Acer      8.0  1 TB HDD 128 GB SSD    i5 7th Gen
# 11           11       Asus      8.0  1 TB HDD 128 GB SSD    i5 8th Gen
# ...

# %% [markdown]
# ### Further data cleaning for better analysis

# %%
L2.drop(columns='Unnamed: 0',inplace=True)

# %%
L2
# Out:
#         Brands  Ram[GB]              Storage     Processor  \
# 0         Acer      8.0  1 TB HDD 128 GB SSD    i5 8th Gen
# 1          MSI     16.0           512 GB SSD    i7 8th Gen
# 2         Asus      8.0  1 TB HDD 128 GB SSD    i7 7th Gen
# 3         Asus      8.0  1 TB HDD 128 GB SSD    i5 8th Gen
# 4          MSI     16.0  1 TB HDD 512 GB SSD    i7 8th Gen
# 5         Asus      8.0  1 TB HDD 128 GB SSD    i7 7th Gen
# 6         Asus      8.0             1 TB HDD    i7 7th Gen
# 7         Asus      8.0  1 TB HDD 256 GB SSD    i7 7th Gen
# 8         Acer      8.0  1 TB HDD 128 GB SSD    i5 7th Gen
# 9          MSI      8.0  1 TB HDD 128 GB SSD    i7 7th Gen
# 10        Acer      8.0  1 TB HDD 128 GB SSD    i5 7th Gen
# 11        Asus      8.0  1 TB HDD 128 GB SSD    i5 8th Gen
# 12         MSI     16.0  1 TB HDD 128 GB SSD    i7 8th Gen
# 13        Asus      8.0             1 TB HDD    i7 7th Gen
# 14      Lenovo      8.0  1 TB HDD 128 GB SSD    i5 7th Gen
# ...

# %%
L2.isnull().sum()
# Out:
# Brands                0
# Ram[GB]               0
# Storage               0
# Processor             0
# Model               117
# Rating                0
# Disc_price            0
# No of Ratings         0
# No of Reviews         0
# Operating system      0
# dtype: int64

# %%
L2['Model'].fillna('---',inplace=True)

# %%
L2
# Out:
#         Brands  Ram[GB]              Storage     Processor  \
# 0         Acer      8.0  1 TB HDD 128 GB SSD    i5 8th Gen
# 1          MSI     16.0           512 GB SSD    i7 8th Gen
# 2         Asus      8.0  1 TB HDD 128 GB SSD    i7 7th Gen
# 3         Asus      8.0  1 TB HDD 128 GB SSD    i5 8th Gen
# 4          MSI     16.0  1 TB HDD 512 GB SSD    i7 8th Gen
# 5         Asus      8.0  1 TB HDD 128 GB SSD    i7 7th Gen
# 6         Asus      8.0             1 TB HDD    i7 7th Gen
# 7         Asus      8.0  1 TB HDD 256 GB SSD    i7 7th Gen
# 8         Acer      8.0  1 TB HDD 128 GB SSD    i5 7th Gen
# 9          MSI      8.0  1 TB HDD 128 GB SSD    i7 7th Gen
# 10        Acer      8.0  1 TB HDD 128 GB SSD    i5 7th Gen
# 11        Asus      8.0  1 TB HDD 128 GB SSD    i5 8th Gen
# 12         MSI     16.0  1 TB HDD 128 GB SSD    i7 8th Gen
# 13        Asus      8.0             1 TB HDD    i7 7th Gen
# 14      Lenovo      8.0  1 TB HDD 128 GB SSD    i5 7th Gen
# ...

# %%
704-117
# Out:
# 587

# %%
L2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 704 entries, 0 to 703
# Data columns (total 10 columns):
# Brands              704 non-null object
# Ram[GB]             704 non-null float64
# Storage             704 non-null object
# Processor           704 non-null object
# Model               704 non-null object
# Rating              704 non-null float64
# Disc_price          704 non-null int64
# No of Ratings       704 non-null float64
# No of Reviews       704 non-null float64
# Operating system    704 non-null object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 55.1+ KB

# %%
L2[L2['Brands']=='Apple']
# Out:
#     Brands  Ram[GB]                Storage          Processor  \
# 17   Apple      8.0             128 GB SSD         i5 5th Gen
# 107  Apple      8.0             256 GB SSD         i5 8th Gen
# 194  Apple      8.0             256 GB SSD         i5 8th Gen
# 244  Apple      8.0             512 GB SSD         i5 7th Gen
# 320  Apple     16.0  512 GB HDD 512 GB SSD         i7 5th Gen
# 359  Apple      8.0             512 GB SSD         i5 5th Gen
# 416  Apple      4.0             128 GB SSD         i5 5th Gen
# 428  Apple     16.0             256 GB SSD         i7 8th Gen
# 484  Apple     16.0             512 GB SSD         i7 7th Gen
# 644  Apple      8.0             128 GB SSD         i5 8th Gen
# 654  Apple     16.0             512 GB SSD         i7 7th Gen
# 658  Apple      8.0             128 GB SSD         i5 7th Gen
# 672  Apple     16.0             512 GB SSD  i7 Processor16 GB
# 691  Apple      8.0             512 GB SSD         i5 8th Gen
# ...

# %%
L2[L2['Brands']=='Alienware']
# Out:
#         Brands  Ram[GB]              Storage   Processor Model  Rating  \
# 114  Alienware      8.0             1 TB HDD  i5 6th Gen   ---     0.0
# 119  Alienware     16.0  1 TB HDD 512 GB SSD  i7 6th Gen   ---     5.0
# 138  Alienware     16.0  1 TB HDD 512 GB SSD  i7 7th Gen   ---     0.0
# 178  Alienware     16.0             1 TB HDD  i7 6th Gen   ---     4.4
# 350  Alienware      8.0  1 TB HDD 256 GB SSD  i7 7th Gen   ---     4.4
#
#      Disc_price  No of Ratings  No of Reviews Operating system
# 114      122990            0.0            0.0  Windows 10 Home
# 119      198000            1.0            1.0  Windows 10 Home
# 138      189990            0.0            0.0  Windows 10 Home
# 178      162000           24.0           15.0  Windows 10 Home
# 350      173127           17.0            4.0  Windows 10 Home

# %%
L2.sort_values(by='Disc_price',ascending=False)
# Out:
#         Brands  Ram[GB]                Storage             Processor  \
# 186        MSI     32.0    1 TB HDD 512 GB SSD            i7 8th Gen
# 677        MSI     32.0      1 TB HDD 1 TB SSD            i9 9th Gen
# 586         HP     16.0               1 TB SSD            i7 8th Gen
# 600       Asus     32.0               1 TB SSD            i7 9th Gen
# 438         HP     16.0               2 TB SSD            i9 9th Gen
# 174        MSI     32.0               1 TB SSD            i7 9th Gen
# 403         HP     16.0               1 TB SSD            i7 9th Gen
# 654      Apple     16.0             512 GB SSD            i7 7th Gen
# 702        MSI     16.0               1 TB SSD            i7 9th Gen
# 484      Apple     16.0             512 GB SSD            i7 7th Gen
# 662       Asus     32.0               1 TB SSD            i7 9th Gen
# 248        MSI     16.0    1 TB HDD 256 GB SSD            i7 7th Gen
# 408         HP     16.0             512 GB SSD            i7 9th Gen
# ...

# %% [markdown]
# ### Converting the data frame after data claening to csv file

# %%
L2.to_csv("Complete cleaned csv")
