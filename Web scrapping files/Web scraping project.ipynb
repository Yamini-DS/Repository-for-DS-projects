# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import numpy as np
import pandas as pd
import re
from bs4 import BeautifulSoup
import requests

# %%
data = requests.get("https://www.flipkart.com/dell-14-3000-core-i3-7th-gen-4-gb-1-tb-hdd-linux-inspiron-3481-laptop/p/itm466e453c2270b?pid=COMFHTHRNDH3EZ2E&lid=LSTCOMFHTHRNDH3EZ2EL4GUOF&marketplace=FLIPKART&fm=neo%2Fmerchandising&iid=M_2880cac1-e06f-4fd9-a5e6-a61f1f33f0ab_11_33033b38-3470-46f8-8da8-5e7173a25b22_DesktopSite_MC.COMFHTHRNDH3EZ2E&ppt=clp&ppn=laptops-store&ssid=f19ml9g13k0000001574932546675&otracker=clp_pmu_v2_Laptops%2Bon%2BExchange_1_11.productCard.PMU_V2_Dell%2B14%2B3000%2BCore%2Bi3%2B7th%2BGen%2B-%2B%25284%2BGB%252F1%2BTB%2BHDD%252FLinux%2529%2Binspiron%2B3481%2BLaptop_laptops-store_COMFHTHRNDH3EZ2E_neo%2Fmerchandising_0&otracker1=clp_pmu_v2_PINNED_neo%2Fmerchandising_Laptops%2Bon%2BExchange_LIST_productCard_cc_1_NA_view-all&cid=COMFHTHRNDH3EZ2E")
data
data1 = requests.get("https://www.flipkart.com/laptops-store?otracker=nmenu_sub_Electronics_0_Laptops")
data1
# Out:
# <Response [200]>
# <Response [200]>

# %%
data.text
data1.text
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n\t<link href="https://rukminim1.flixcart.com" rel="dns-prefetch" />\n\t<link href="https://img1a.flixcart.com" rel="dns-prefetch" />\n\t<link rel="stylesheet" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.82a2ce.css" />\n\n\t<link rel="preload" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" as="image">\n\n\t<meta http-equiv="Content-type" content="text/html; charset=utf-8"/>\n\t<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\n\t<meta property="fb:page_id" content="102988293558"/>\n\t<meta property="fb:admins" content="658873552,624500995,100000233612389"/>\n\t<meta name="robots" content="noodp" />\n\n\t<link rel=\'shortcut icon\' href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" />\n\n\t<link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/>\n\n\t<meta property="og:type" content="website"/>\n\t<meta name="og_site_name" pro
# ...

# %%
data_soup = BeautifulSoup(data.text)
data_soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/>
# <link href="https://img1a.flixcart.com" rel="dns-prefetch"/>
# <link href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.82a2ce.css" rel="stylesheet"/>
# <link as="image" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" rel="preload"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="102988293558" property="fb:page_id"/>
# <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
# <meta content="noodp" name="robots"/>
# <link href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
# <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
# <meta content="website" property="og:type"/>
# ...

# %%
data_soup1 = BeautifulSoup(data1.text)
data_soup1
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/>
# <link href="https://img1a.flixcart.com" rel="dns-prefetch"/>
# <link href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.82a2ce.css" rel="stylesheet"/>
# <link as="image" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" rel="preload"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="102988293558" property="fb:page_id"/>
# <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
# <meta content="noodp" name="robots"/>
# <link href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
# <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
# <meta content="website" property="og:type"/>
# ...

# %%
req = data_soup.find_all('span',class_='_35KyD6')
req[0].text
# Out:
# 'Dell 14 3000 Core i3 7th Gen - (4 GB/1 TB HDD/Linux) inspiron 3481 Laptop\xa0\xa0(14 inch, Platinum Silver, 1.79 kg)'

# %%
req2 = data_soup1.find_all('div',class_='_3liAhj _2Vsm67')
req2
# Out:
# [<div class="_3liAhj _2Vsm67"><a class="Zhf2z-" href="/msi-gf63-thin-core-i7-9th-gen-8-gb-512-gb-ssd-windows-10-home-4-graphics-9sc-460in-gaming-laptop/p/itmaeda9251d64fd?pid=COMFHBWSTWBPNGYA&amp;lid=LSTCOMFHBWSTWBPNGYANHOZNM&amp;marketplace=FLIPKART&amp;fm=neo%2Fmerchandising&amp;iid=M_d111927e-2818-451e-b4cc-a37ea7f8b447_11_33033b38-3470-46f8-8da8-5e7173a25b22_DesktopSite_MC.COMFHBWSTWBPNGYA&amp;ssid=0j0osh0meo0000001575222660237&amp;otracker=clp_pmu_v2_Laptops%2Bon%2BExchange_1_11.productCard.PMU_V2_MSI%2BGF63%2BThin%2BCore%2Bi7%2B9th%2BGen%2B-%2B%25288%2BGB%252F512%2BGB%2BSSD%252FWindows%2B10%2BHome%252F4%2BGB%2BGraphics%2529%2BGF63%2BThin%2B9SC-460IN%2BGaming%2BLaptop_laptops-store_COMFHBWSTWBPNGYA_neo%2Fmerchandising_0&amp;otracker1=clp_pmu_v2_PINNED_neo%2Fmerchandising_Laptops%2Bon%2BExchange_LIST_productCard_cc_1_NA_view-all&amp;cid=COMFHBWSTWBPNGYA" rel="noopener noreferrer" target="_blank" title="MSI GF63 Thin Core i7 9th Gen - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics
# ...

# %%
for i in req2:
    print(i.text)
# Out:
# MSI GF63 Thin Core i7 9th Gen - (8 GB/512 GB SSD/Windows 10 Home/...4.5(143)₹69,990₹93,29024% off
# Apple MacBook Air Core i5 5th Gen - (8 GB/128 GB SSD/Mac OS Sierr...4.7(20,825)₹54,990₹84,90035% off
# HP 14q APU Dual Core A9 - (4 GB/256 GB SSD/Windows 10 Home) 14q-c...4.1(6,911)₹19,990₹27,62127% off
# Dell Vostro 3000 Core i5 8th Gen - (8 GB/1 TB HDD/Windows 10 Home...4.1(184)₹38,990₹45,17413% off
# MSI Core i5 9th Gen - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graph...4.6(469)₹54,990₹83,49034% off
# HP 15q APU Dual Core A9 - (4 GB/1 TB HDD/Windows 10 Home) 15q-dy0...4.1(6,911)₹19,990₹29,63132% off
# Lenovo Ideapad Core i3 6th Gen - (4 GB/1 TB HDD/DOS) IP 320E Lapt...4.1(6,242)₹26,990₹31,49014% off
# Lenovo Core i5 7th Gen - (8 GB/1 TB HDD/DOS/2 GB Graphics) IP 320...4.3(13,087)₹52,990₹54,0001% off
# Lenovo Ideapad Core i5 7th Gen - (8 GB/1 TB HDD/Windows 10 Home/2...4.3(13,087)₹52,990₹53,7451% off
# ...

# %%
data=[]
for i in req2:
    data.append(i.text)

# %%
data
# Out:
# ['MSI GF63 Thin Core i7 9th Gen - (8 GB/512 GB SSD/Windows 10 Home/...4.5(143)₹69,990₹93,29024% off',
#  'Apple MacBook Air Core i5 5th Gen - (8 GB/128 GB SSD/Mac OS Sierr...4.7(20,825)₹54,990₹84,90035% off',
#  'HP 14q APU Dual Core A9 - (4 GB/256 GB SSD/Windows 10 Home) 14q-c...4.1(6,911)₹19,990₹27,62127% off',
#  'Dell Vostro 3000 Core i5 8th Gen - (8 GB/1 TB HDD/Windows 10 Home...4.1(184)₹38,990₹45,17413% off',
#  'MSI Core i5 9th Gen - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graph...4.6(469)₹54,990₹83,49034% off',
#  'HP 15q APU Dual Core A9 - (4 GB/1 TB HDD/Windows 10 Home) 15q-dy0...4.1(6,911)₹19,990₹29,63132% off',
#  'Lenovo Ideapad Core i3 6th Gen - (4 GB/1 TB HDD/DOS) IP 320E Lapt...4.1(6,242)₹26,990₹31,49014% off',
#  'Lenovo Core i5 7th Gen - (8 GB/1 TB HDD/DOS/2 GB Graphics) IP 320...4.3(13,087)₹52,990₹54,0001% off',
#  'Lenovo Ideapad Core i5 7th Gen - (8 GB/1 TB HDD/Windows 10 Home/2...4.3(13,087)₹52,990₹53,7451% off',
# ...

# %%
req3 = data_soup1.find_all('div',class_='_3BEcOp')
req3
# Out:
# [<div class="_3BEcOp"><div class="EstLIe" style="width:1642px"><div class="_2NTrR2" style="-webkit-transform:translateX(0px);-moz-transform:translateX(0px);-o-transform:translateX(0px);-ms-transform:translateX(0px);transform:translateX(0px)"><div class="_2kSfQ4" style="width:204px"><div><a class="_29UPft" href="/laptops/hp~brand/pr?sid=6bo,b5g&amp;otracker=clp_metro_expandable_1_5.metroExpandable.METRO_EXPANDABLE_HP_laptops-store_ZCQFAP2R5I_wp4&amp;fm=neo%2Fmerchandising&amp;iid=M_d111927e-2818-451e-b4cc-a37ea7f8b447_5.ZCQFAP2R5I&amp;ssid=0j0osh0meo0000001575222660237"><div class="_3b7jyH"><img alt="HP" class="_1N-ymU" src="https://rukminim1.flixcart.com/merch/240/240/images/1492250340280.jpg?q=90"/></div><p class="yHn1qE">HP</p></a></div></div><div class="_2kSfQ4" style="width:204px"><div><a class="_29UPft" href="/laptops/dell~brand/pr?sid=6bo,b5g&amp;otracker=clp_metro_expandable_2_5.metroExpandable.METRO_EXPANDABLE_Dell_laptops-store_LVL7DAHQW9_wp4&amp;fm=neo%2Fmerchandising&amp;i
# ...

# %%
for i in data:
    print(str(i).split('-')[0])
# Out:
# MSI GF63 Thin Core i7 9th Gen
# Apple MacBook Air Core i5 5th Gen
# HP 14q APU Dual Core A9
# Dell Vostro 3000 Core i5 8th Gen
# MSI Core i5 9th Gen
# HP 15q APU Dual Core A9
# Lenovo Ideapad Core i3 6th Gen
# Lenovo Core i5 7th Gen
# Lenovo Ideapad Core i5 7th Gen
# Lenovo Core i5 7th Gen
# Lenovo Core i3 6th Gen
# HP Core i5 7th Gen

# %%
for i in req3:
    print(i.text)
# Out:
# HPDellLenovoAcerASUSi-LifeAPPLEMicrosoft
# under ₹15,000₹15,000 to ₹25,000₹25,000 to ₹35,000₹35,000 to ₹50,000₹50,000 to ₹70,000From 70k
# MSI GF63 Thin Core i7 9th Gen - (8 GB/512 GB SSD/Windows 10 Home/...4.5(143)₹69,990₹93,29024% offApple MacBook Air Core i5 5th Gen - (8 GB/128 GB SSD/Mac OS Sierr...4.7(20,825)₹54,990₹84,90035% offHP 14q APU Dual Core A9 - (4 GB/256 GB SSD/Windows 10 Home) 14q-c...4.1(6,911)₹19,990₹27,62127% offDell Vostro 3000 Core i5 8th Gen - (8 GB/1 TB HDD/Windows 10 Home...4.1(184)₹38,990₹45,17413% offMSI Core i5 9th Gen - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graph...4.6(469)₹54,990₹83,49034% offHP 15q APU Dual Core A9 - (4 GB/1 TB HDD/Windows 10 Home) 15q-dy0...4.1(6,911)₹19,990₹29,63132% off
# ...

# %%
data5=[]
for i in req3:
    data.append(i.text)

# %%
for i in data5:
    print(str(i).split('-')[0])

# %%
Model=[]
for i in req2:
    a=i.text
    model = re.search(r'[A-Z]\w+',a)
    if model:
        Model.append(model.group)
Model
# Out:
# [<function Match.group>,
#  <function Match.group>,
#  <function Match.group>,
#  <function Match.group>,
#  <function Match.group>,
#  <function Match.group>,
#  <function Match.group>,
#  <function Match.group>,
#  <function Match.group>,
#  <function Match.group>,
#  <function Match.group>,
#  <function Match.group>]

# %%
data6 = requests.get("https://www.flipkart.com/laptops/~gaming/pr?count=40&p[]=sort=popularity&sid=6bo/b5g&fm=neo%2Fmerchandising&iid=M_0f7ed54f-5116-4f66-abbd-4b6482f10625_1.OII6GWID97&ppt=dynamic&ppn=dynamic&ssid=pqx82x3l5s0000001574937858283&otracker=dynamic_omu_infinite_Limited%2BPeriod%2BDeals_1_1.dealCard.OMU_INFINITE_OII6GWID97&cid=OII6GWID97")
data6
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      56
# ---> 57     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      58         af, socktype, proto, canonname, sa = res
#
# ~\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# ...

# %%
data6.text
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n\t<link href="https://rukminim1.flixcart.com" rel="dns-prefetch" />\n\t<link href="https://img1a.flixcart.com" rel="dns-prefetch" />\n\t<link rel="stylesheet" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.82a2ce.css" />\n\n\t<link rel="preload" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" as="image">\n\n\t<meta http-equiv="Content-type" content="text/html; charset=utf-8"/>\n\t<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\n\t<meta property="fb:page_id" content="102988293558"/>\n\t<meta property="fb:admins" content="658873552,624500995,100000233612389"/>\n\t<meta name="robots" content="noodp" />\n\n\t<link rel=\'shortcut icon\' href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" />\n\n\t<link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/>\n\n\t<meta property="og:type" content="website"/>\n\t<meta name="og_site_name" pro
# ...

# %%
data_soup3 = BeautifulSoup(data6.text)
data_soup3
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/>
# <link href="https://img1a.flixcart.com" rel="dns-prefetch"/>
# <link href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.82a2ce.css" rel="stylesheet"/>
# <link as="image" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" rel="preload"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="102988293558" property="fb:page_id"/>
# <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
# <meta content="noodp" name="robots"/>
# <link href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
# <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
# <meta content="website" property="og:type"/>
# ...

# %%
req8 = data_soup3.find_all('div',attrs={"class":"_1-2Iqu row"})
req8
# Out:
# [<div class="_1-2Iqu row"><div class="col col-7-12"><div class="_3wU53n">Acer Predator Helios 300 Core i5 8th Gen - (8 GB/1 TB HDD/128 GB SSD/Windows 10 Home/4 GB Graphics) PH...</div><div class="niH0FQ"><span class="_2_KrJI" id="productRating_LSTCOMF5NVPQAZDMZFBBVX5AO_COMF5NVPQAZDMZFB_"><div class="hGSR34">4.6<img class="_2lQ_WZ" src="..."/></div></span><span class="_38sUEc"><span><span>11,511 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 1,557 Reviews</span></span></span></div><div class="_3ULzGw"><ul class="vFw0gD"><li class="tVe95H">NVIDIA Geforce GTX 1050 Ti for Desktop Level Performance</li><li class="tVe95H">Optimized Dolby Audio Premium Sound Enhancement</li><li class="tVe95H">128 GB SSD Capacity for Reduced Boot Up Time and in Game Loading</li><li class="tVe95H">Dual Fan Cooling with Metal AeroBlade for Interuption Free Gaming</li><li class="tVe95H">FineTip Backlit Keyboard with Independent Standard Numeric Keypad</li><li class="tVe95H">Intel Core i5 Processor (8th
# ...

# %%
Laptop=[]
Rating=[]
Disc_price=[]
Processor=[]
Ram1=[]
Os =[]

# %%
for i in req8:
    laptop=i.find('div',class_="_3wU53n").text
    print(laptop)
    Laptop.append(laptop)
    rating=i.find('div',class_='hGSR34').text
    print(rating)
    Rating.append(rating)
    disc_price = i.find('div',class_='_1vC4OE _2rQ-NK').text
    print(disc_price)
    Disc_price.append(disc_price)
    #os = i.find('li',class_='tVe95H').text
    #print(os)
    #Os.append(os)
    
for item in req8:
    match3 = re.findall(r'i\d\s\w+\s\w+',item.text)
    if match3:
        Processor.append((match3[0]))
    else:
        Processor.append('NaN')
        
for item in req8:
    match1 = re.findall(r'[(]\b\d+\s\w+\b',i.text)
    if match1:
        #a.append((match1[0]))
        #b = ' '.join(match1[0])
        #b
        c = re.findall(r'\d+',match1[0])
        Ram = ' '.join(c)
        Ram1.append(Ram)
for i in req8:
    match4 = re.findall(r'[SSD/]\b\w+\s\d+\s\w+|[HDD/]\b\w+\s\d+',i.text)
    if match4:
        b = re.findall(r'\w+\s\d+\s\w+',match4[0])
        if b:
            os = ' '.join(b)
            Os.append(os)
        else:
            b = re.findall(r'\w+\s\d+',match4[0])
            os=' '.join(b)
            Os.append(os)
    else:
        Os.append(np.nan)

    
    
print(Laptop)
print(Rating)
print(Disc_price)
print(Processor)
print(Ram)
print(os)
# Out:
# Acer Predator Helios 300 Core i5 8th Gen - (8 GB/1 TB HDD/128 GB SSD/Windows 10 Home/4 GB Graphics) PH...
# 4.6
# ₹55,990
# MSI GS Core i7 8th Gen - (16 GB/512 GB SSD/Windows 10 Home/6 GB Graphics) GS65 8RE-084IN Gaming Laptop
# 4
# ₹1,49,990
# Asus ROG Strix Edition Core i7 7th Gen - (8 GB/1 TB HDD/128 GB SSD/Windows 10 Home/4 GB Graphics) GL50...
# 4
# ₹92,990
# Asus FX503 Core i7 7th Gen - (8 GB/1 TB HDD/128 GB SSD/Windows 10 Home/4 GB Graphics) FX503VD-DM112T G...
# 5
# ₹87,990
# Asus TUF Core i5 8th Gen - (8 GB/1 TB HDD/128 GB SSD/Windows 10 Home/4 GB Graphics) FX504GE-E4366T Gam...
# 4.5
# ₹66,990
# Asus ROG Core i7 7th Gen - (8 GB/1 TB HDD/Windows 10 Home/4 GB Graphics) GL553VD-FY103T Gaming Laptop
# 4.3
# ₹1,07,990
# Asus TUF Core i5 8th Gen - (8 GB/1 TB HDD/Windows 10 Home/4 GB Graphics) FX504GD-E4021T Gaming Laptop
# 4.4
# ₹74,990
# Asus ROG Core i7 7th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 10 Home/6 GB Graphics) GL502VM-FY230T Gam...
# 3
# ₹1,46,490
# ...

# %%
#print('1 - ', match4[0])

#print('2 - ', match4)
#print(b)
#print('3 - ', Disc_price)
#print('4 - ', disc_price)
for i in Disc_price:
    #c = re.findall(r'\d+\d+',disc_price)
    #print(c)
    b=i.replace(",","")
    print(b[1:])
    Disc_price.append(b[1:])
    #c = re.findall(r'\d+',b)
    #Disc_price(c)
print(Disc_price)

# %%
print(os)
print(Laptop)
print(Os)
# Out:
# Windows 10 Home
# ...

# %%
a=[]
Ram1=[]
for i in req8:
    match1 = re.findall(r'[(]\b\d+\s\w+\b',i.text)
    if match1:
        #a.append((match1[0]))
        #b = ' '.join(match1[0])
        #b
        c = re.findall(r'\d+',match1[0])
        Ram = ' '.join(c)
        Ram1.append(Ram)
        
print(Ram1)
len(Ram1)
len(Ram)
print(Ram)
# Out:
# ['8', '16', '8', '8', '8', '8', '8', '8', '8', '8', '8', '16', '16', '8', '8', '8', '16']
# 17
# 2
# 16

# %%
print(Ram)
# Out:
# 16

# %%
print(Ram1)
# Out:
# ['8', '16', '8', '8', '8', '8', '8', '8', '8', '8', '8', '16', '16', '8', '8', '8', '16']

# %%
print(a)
# Out:
# []

# %%
b = ' '.join(a)
b
# Out:
# ''

# %%
Ram1 = re.findall(r'\d+',b)
Ram1
# Out:
# []

# %%
print(Ram1)
# Out:
# []

# %%
Ram.append(Ram1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-78f702a25bcc> in <module>
# ----> 1 Ram.append(Ram1)
#
# AttributeError: 'str' object has no attribute 'append'

# %%
Ram1 = Ram
Ram
# Out:
# '16'

# %%
for i in Laptop:
    print(str(i).split('-')[0])
# Out:
# Acer Predator Helios 300 Core i5 8th Gen
# MSI GS Core i7 8th Gen
# Asus FX503 Core i7 7th Gen
# Asus TUF Core i5 8th Gen
# Asus ROG Strix Edition Core i7 7th Gen
# Asus ROG Core i7 7th Gen
# Asus ROG Core i7 7th Gen
# Acer Predator Helios 300 Core i5 7th Gen
# Acer Nitro 5 Core i5 7th Gen
# Asus TUF Core i5 8th Gen
# MSI GL Series Core i7 7th Gen
# MSI GE Core i7 8th Gen
# MSI GV Series Core i7 8th Gen
# Asus FX553 Core i7 7th Gen
# Lenovo Legion Core i5 7th Gen
# MSI GL Core i7 8th Gen
# Asus ROG Strix Edition Core i7 8th Gen

# %%
Laptops=pd.DataFrame()
Laptops['Laptop']=Laptop
Laptops['Rating']=Rating
Laptops['Disc_price']=Disc_price
Laptops['Processor']=Processor
Laptops['Ram[GB]']=Ram1
Laptops['OS'] = Os
Laptops

# %%
Processor=[]

# %%
for item in req8:
    match = re.findall(r'i\d\s\w+\s\w+',item.text)
    if match:
        Processor.append((match[0]))

# %%
len(Processor)
# Out:
# 17

# %%
Processor
# Out:
# ['i5 8th Gen',
#  'i7 8th Gen',
#  'i7 7th Gen',
#  'i5 8th Gen',
#  'i7 7th Gen',
#  'i7 7th Gen',
#  'i7 7th Gen',
#  'i5 7th Gen',
#  'i5 7th Gen',
#  'i5 8th Gen',
#  'i7 7th Gen',
#  'i7 8th Gen',
#  'i7 8th Gen',
#  'i7 7th Gen',
#  'i5 7th Gen',
#  'i7 8th Gen',
#  'i7 8th Gen']

# %%
Laptops['Processor']=Processor

# %%
Laptops
# Out:
#                                                Laptop Rating Disc_price  \
# 0   Acer Predator Helios 300 Core i5 8th Gen - (8 ...    4.6    ₹55,990
# 1   MSI GS Core i7 8th Gen - (16 GB/512 GB SSD/Win...      4  ₹1,49,990
# 2   Asus FX503 Core i7 7th Gen - (8 GB/1 TB HDD/12...      5    ₹87,990
# 3   Asus TUF Core i5 8th Gen - (8 GB/1 TB HDD/128 ...    4.5    ₹66,990
# 4   Asus ROG Strix Edition Core i7 7th Gen - (8 GB...      4    ₹92,990
# 5   Asus ROG Core i7 7th Gen - (8 GB/1 TB HDD/Wind...    4.3  ₹1,07,990
# 6   Asus ROG Core i7 7th Gen - (8 GB/1 TB HDD/256 ...      3  ₹1,46,490
# 7   Acer Predator Helios 300 Core i5 7th Gen - (8 ...    4.5  ₹1,29,999
# 8   Acer Nitro 5 Core i5 7th Gen - (8 GB/1 TB HDD/...    4.5    ₹52,990
# 9   Asus TUF Core i5 8th Gen - (8 GB/1 TB HDD/128 ...    4.3    ₹72,990
# 10  MSI GL Series Core i7 7th Gen - (8 GB/1 TB HDD...    4.9    ₹83,990
# 11  MSI GE Core i7 8th Gen - (16 GB/1 TB HDD/512 G...    4.5  ₹1,79,990
# ...

# %%
Ram=[]

# %%
for i in req8:
    match1 = re.findall(r'[(]\b\d+\s\w+\b',i.text)
    if match1:
        Ram.append((match1[0]))

# %%
Ram
# Out:
# ['(8 GB',
#  '(16 GB',
#  '(8 GB',
#  '(8 GB',
#  '(8 GB',
#  '(8 GB',
#  '(8 GB',
#  '(8 GB',
#  '(8 GB',
#  '(8 GB',
#  '(8 GB',
#  '(16 GB',
#  '(16 GB',
#  '(8 GB',
#  '(8 GB',
#  '(8 GB',
#  '(16 GB']

# %%
len(Ram)
# Out:
# 17

# %%
a = ' '.join(Ram)

# %%
a
# Out:
# '(8 GB (16 GB (8 GB (8 GB (8 GB (8 GB (8 GB (8 GB (8 GB (8 GB (8 GB (16 GB (16 GB (8 GB (8 GB (8 GB (16 GB'

# %%
match2 = re.findall(r'\d+\s',a)

# %%
match2
# Out:
# ['8 ',
#  '16 ',
#  '8 ',
#  '8 ',
#  '8 ',
#  '8 ',
#  '8 ',
#  '8 ',
#  '8 ',
#  '8 ',
#  '8 ',
#  '16 ',
#  '16 ',
#  '8 ',
#  '8 ',
#  '8 ',
#  '16 ']

# %%
Laptops['Ram(GB)']= match2

# %%
Laptops
# Out:
#                                                Laptop Rating Disc_price  \
# 0   Acer Predator Helios 300 Core i5 8th Gen - (8 ...    4.6    ₹55,990
# 1   MSI GS Core i7 8th Gen - (16 GB/512 GB SSD/Win...      4  ₹1,49,990
# 2   Asus FX503 Core i7 7th Gen - (8 GB/1 TB HDD/12...      5    ₹87,990
# 3   Asus TUF Core i5 8th Gen - (8 GB/1 TB HDD/128 ...    4.5    ₹66,990
# 4   Asus ROG Strix Edition Core i7 7th Gen - (8 GB...      4    ₹92,990
# 5   Asus ROG Core i7 7th Gen - (8 GB/1 TB HDD/Wind...    4.3  ₹1,07,990
# 6   Asus ROG Core i7 7th Gen - (8 GB/1 TB HDD/256 ...      3  ₹1,46,490
# 7   Acer Predator Helios 300 Core i5 7th Gen - (8 ...    4.5  ₹1,29,999
# 8   Acer Nitro 5 Core i5 7th Gen - (8 GB/1 TB HDD/...    4.5    ₹52,990
# 9   Asus TUF Core i5 8th Gen - (8 GB/1 TB HDD/128 ...    4.3    ₹72,990
# 10  MSI GL Series Core i7 7th Gen - (8 GB/1 TB HDD...    4.9    ₹83,990
# 11  MSI GE Core i7 8th Gen - (16 GB/1 TB HDD/512 G...    4.5  ₹1,79,990
# ...

# %%
data2 = requests.get("https://www.flipkart.com/laptops/pr?sid=b5g")
data2
# Out:
# <Response [200]>

# %%
data2.text
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n\t<link href="https://rukminim1.flixcart.com" rel="dns-prefetch" />\n\t<link href="https://img1a.flixcart.com" rel="dns-prefetch" />\n\t<link rel="stylesheet" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.82a2ce.css" />\n\n\t<link rel="preload" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" as="image">\n\n\t<meta http-equiv="Content-type" content="text/html; charset=utf-8"/>\n\t<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\n\t<meta property="fb:page_id" content="102988293558"/>\n\t<meta property="fb:admins" content="658873552,624500995,100000233612389"/>\n\t<meta name="robots" content="noodp" />\n\n\t<link rel=\'shortcut icon\' href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" />\n\n\t<link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/>\n\n\t<meta property="og:type" content="website"/>\n\t<meta name="og_site_name" pro
# ...

# %%
data_soup3 = BeautifulSoup(data2.text)
data_soup3
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/>
# <link href="https://img1a.flixcart.com" rel="dns-prefetch"/>
# <link href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.82a2ce.css" rel="stylesheet"/>
# <link as="image" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" rel="preload"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="102988293558" property="fb:page_id"/>
# <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
# <meta content="noodp" name="robots"/>
# <link href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
# <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
# <meta content="website" property="og:type"/>
# ...

# %%
req_data2 = data_soup3.find_all('div',attrs={"class":"_1-2Iqu row"})
req_data2
# Out:
# [<div class="_1-2Iqu row"><div class="col col-7-12"><div class="_3wU53n">Apple MacBook Air Core i5 5th Gen - (8 GB/128 GB SSD/Mac OS Sierra) MQD32HN/A A1466</div><div class="niH0FQ"><span class="_2_KrJI" id="productRating_LSTCOMEVCPQBXBDFJ8C4V6AHG_COMEVCPQBXBDFJ8C_"><div class="hGSR34">4.7<img class="_2lQ_WZ" src="..."/></div></span><span class="_38sUEc"><span><span>20,825 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 2,408 Reviews</span></span></span></div><div class="_3ULzGw"><ul class="vFw0gD"><li class="tVe95H">Intel Core i5 Processor (5th Gen)</li><li class="tVe95H">8 GB DDR3 RAM</li><li class="tVe95H">64 bit Mac OS Operating System</li><li class="tVe95H">128 GB SSD</li><li class="tVe95H">33.78 cm (13.3 inch) Display</li><li class="tVe95H">1 Year Carry In Warranty</li></ul></div></div><div class="col col-5-12 _2o7WAb"><div class="_6BWGkk"><div class="_1uv9Cb"><div class="_1vC4OE _2rQ-NK">₹54,990</div><div class="_3auQ3N _2GcJzG">₹<!-- -->84,900</div><div class="VGWI6T"
# ...

# %%
for i in req_data2:
    laptop=i.find('div',class_="_3wU53n").text
    print(laptop)
    Laptop.append(laptop)
    rating=i.find('div',class_='hGSR34').text
    print(rating)
    Rating.append(rating)
    disc_price = i.find('div',class_="_1vC4OE _2rQ-NK").text
    print(disc_price)
    Disc_price.append(disc_price)
    
    for item in req_data2:
        match3 = re.findall(r'i\d\s\w+\s\w+',item.text)
    if match3:
        Processor.append((match3[0]))
    else:
        Processor.append('NaN')

    
    
print(Laptop)
print(Rating)
print(Disc_price)
print(Processor)
# Out:
# Apple MacBook Air Core i5 5th Gen - (8 GB/128 GB SSD/Mac OS Sierra) MQD32HN/A A1466
# 4.7
# ₹54,990
# Acer Aspire 3 Ryzen 3 Dual Core - (4 GB/1 TB HDD/Windows 10 Home) A315-42-R414 Laptop
# 4.2
# ₹21,990
# HP 15q APU Dual Core A9 - (4 GB/1 TB HDD/Windows 10 Home) 15q-dy0007AU Laptop
# 4.1
# ₹19,990
# Avita Liber Core i5 8th Gen - (8 GB/256 GB SSD/Windows 10 Home) NS13A2IN214P Thin and Light Laptop
# 4.7
# ₹34,990
# Avita Liber Core i5 8th Gen - (8 GB/256 GB SSD/Windows 10 Home) NS14A2IN201P Thin and Light Laptop
# 4.5
# ₹34,990
# Dell G3 Series Core i5 8th Gen - (8 GB/1 TB HDD/128 GB SSD/Windows 10 Home/4 GB Graphics) 3579 Gaming ...
# 4.4
# ₹54,990
# Dell 14 3000 Core i3 7th Gen - (4 GB/1 TB HDD/Linux) inspiron 3481 Laptop
# 4.1
# ₹23,990
# Asus Core i3 7th Gen - (4 GB/1 TB HDD/Windows 10 Home) X540UA-GQ682T Laptop
# 4
# ₹23,990
# Lenovo Ideapad 130 Core i3 7th Gen - (4 GB/1 TB HDD/Windows 10 Home) 130-15IKB Laptop
# 4.1
# ₹25,990
# ...

# %%
for item in L1:
    match3 = re.findall(r'i\d\s\w+\s\w+',item.text)
    if match3:
        Processor.append((match3[0]))
    else:
        Processor.append('NaN')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-99b95041a283> in <module>
# ----> 1 for item in L1:
#       2     match3 = re.findall(r'i\d\s\w+\s\w+',item.text)
#       3     if match3:
#       4         Processor.append((match3[0]))
#       5     else:
#
# NameError: name 'L1' is not defined

# %%
Laptops1=pd.DataFrame()
Laptops1['Laptop']=Laptop
Laptops1['Rating']=Rating
Laptops1['Disc_price']=Disc_price
Laptops1['Processor']=Processor

Laptops1
# Out:
#                                                Laptop Rating Disc_price  \
# 0   Acer Predator Helios 300 Core i5 8th Gen - (8 ...    4.6    ₹55,990
# 1   MSI GS Core i7 8th Gen - (16 GB/512 GB SSD/Win...      4  ₹1,49,990
# 2   Asus FX503 Core i7 7th Gen - (8 GB/1 TB HDD/12...      5    ₹87,990
# 3   Asus TUF Core i5 8th Gen - (8 GB/1 TB HDD/128 ...    4.5    ₹66,990
# 4   Asus ROG Strix Edition Core i7 7th Gen - (8 GB...      4    ₹92,990
# 5   Asus ROG Core i7 7th Gen - (8 GB/1 TB HDD/Wind...    4.3  ₹1,07,990
# 6   Asus ROG Core i7 7th Gen - (8 GB/1 TB HDD/256 ...      3  ₹1,46,490
# 7   Acer Predator Helios 300 Core i5 7th Gen - (8 ...    4.5  ₹1,29,999
# 8   Acer Nitro 5 Core i5 7th Gen - (8 GB/1 TB HDD/...    4.5    ₹52,990
# 9   Asus TUF Core i5 8th Gen - (8 GB/1 TB HDD/128 ...    4.3    ₹72,990
# 10  MSI GL Series Core i7 7th Gen - (8 GB/1 TB HDD...    4.9    ₹83,990
# 11  MSI GE Core i7 8th Gen - (16 GB/1 TB HDD/512 G...    4.5  ₹1,79,990
# ...

# %%
Processor=[]

# %%
L1 = ' '.join(Laptop)

# %%
L1
# Out:
# 'Acer Predator Helios 300 Core i5 8th Gen - (8 GB/1 TB HDD/128 GB SSD/Windows 10 Home/4 GB Graphics) PH... MSI GS Core i7 8th Gen - (16 GB/512 GB SSD/Windows 10 Home/6 GB Graphics) GS65 8RE-084IN Gaming Laptop Asus FX503 Core i7 7th Gen - (8 GB/1 TB HDD/128 GB SSD/Windows 10 Home/4 GB Graphics) FX503VD-DM112T G... Asus TUF Core i5 8th Gen - (8 GB/1 TB HDD/128 GB SSD/Windows 10 Home/4 GB Graphics) FX504GE-E4366T Gam... Asus ROG Strix Edition Core i7 7th Gen - (8 GB/1 TB HDD/128 GB SSD/Windows 10 Home/4 GB Graphics) GL50... Asus ROG Core i7 7th Gen - (8 GB/1 TB HDD/Windows 10 Home/4 GB Graphics) GL553VD-FY103T Gaming Laptop Asus ROG Core i7 7th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 10 Home/6 GB Graphics) GL502VM-FY230T Gam... Acer Predator Helios 300 Core i5 7th Gen - (8 GB/1 TB HDD/128 GB SSD/Windows 10 Home/4 GB Graphics) G3... Acer Nitro 5 Core i5 7th Gen - (8 GB/1 TB HDD/128 GB SSD/Windows 10 Home/2 GB Graphics) AN515-51 Gamin... Asus TUF Core i5 8th Gen - (8 GB/1 TB HDD/128 GB S
# ...

# %%
for item in L1:
    match3 = re.findall(r'i\d\s\w+\s\w+',item.text)
    if match3:
        Processor.append((match3[0]))
    else:
        Processor.append('NaN')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-6c33d48bf85e> in <module>
#       1 for item in L1:
# ----> 2     match3 = re.findall(r'i\d\s\w+\s\w+',item.text)
#       3     if match3:
#       4         Processor.append((match3[0]))
#       5     else:
#
# AttributeError: 'str' object has no attribute 'text'

# %%
len(Processor)
# Out:
# 0

# %%
Laptops1['Processor'] = Processor
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-f211dd4a4218> in <module>
# ----> 1 Laptops1['Processor'] = Processor
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3443
#    3444         self._ensure_valid_index(value)
# -> 3445         value = self._sanitize_column(key, value)
#    3446         NDFrame._set_item(self, key, value)
#    3447
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3628
#    3629             # turn me into an ndarray
# ...

# %%
Processor
# Out:
# []

# %%
Laptops1
# Out:
#                                                Laptop Rating Disc_price  \
# 0   Acer Predator Helios 300 Core i5 8th Gen - (8 ...    4.6    ₹55,990
# 1   MSI GS Core i7 8th Gen - (16 GB/512 GB SSD/Win...      4  ₹1,49,990
# 2   Asus FX503 Core i7 7th Gen - (8 GB/1 TB HDD/12...      5    ₹87,990
# 3   Asus TUF Core i5 8th Gen - (8 GB/1 TB HDD/128 ...    4.5    ₹66,990
# 4   Asus ROG Strix Edition Core i7 7th Gen - (8 GB...      4    ₹92,990
# 5   Asus ROG Core i7 7th Gen - (8 GB/1 TB HDD/Wind...    4.3  ₹1,07,990
# 6   Asus ROG Core i7 7th Gen - (8 GB/1 TB HDD/256 ...      3  ₹1,46,490
# 7   Acer Predator Helios 300 Core i5 7th Gen - (8 ...    4.5  ₹1,29,999
# 8   Acer Nitro 5 Core i5 7th Gen - (8 GB/1 TB HDD/...    4.5    ₹52,990
# 9   Asus TUF Core i5 8th Gen - (8 GB/1 TB HDD/128 ...    4.3    ₹72,990
# 10  MSI GL Series Core i7 7th Gen - (8 GB/1 TB HDD...    4.9    ₹83,990
# 11  MSI GE Core i7 8th Gen - (16 GB/1 TB HDD/512 G...    4.5  ₹1,79,990
# ...

# %%
Ram1=[]

# %%
for i in req_data2:
    match1 = re.findall(r'[(]\b\d+\s\w+\b',i.text)
    if match1:
        Ram1.append((match1[0]))

# %%
len(Ram1)
# Out:
# 24

# %%
Ram1[0]
# Out:
# '(8 GB'

# %%
b=' '.join(Ram1)

# %%
b
# Out:
# '(8 GB (4 GB (4 GB (8 GB (8 GB (8 GB (4 GB (4 GB (4 GB (8 GB (8 GB (8 GB (8 GB (8 GB (8 GB (4 GB (4 GB (8 GB (4 GB (4 GB (8 GB (4 GB (8 GB (8 GB'

# %%
match3 = re.findall(r'\d+\s',b)
match3
# Out:
# ['8 ',
#  '4 ',
#  '4 ',
#  '8 ',
#  '8 ',
#  '8 ',
#  '4 ',
#  '4 ',
#  '4 ',
#  '8 ',
#  '8 ',
#  '8 ',
#  '8 ',
#  '8 ',
#  '8 ',
#  '4 ',
#  '4 ',
#  '8 ',
#  '4 ',
#  '4 ',
#  '8 ',
#  '4 ',
#  '8 ',
#  '8 ']

# %%
Laptops1['Ram(GB)']=match3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-c2ed99828d7f> in <module>
# ----> 1 Laptops1['Ram(GB)']=match3
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3443
#    3444         self._ensure_valid_index(value)
# -> 3445         value = self._sanitize_column(key, value)
#    3446         NDFrame._set_item(self, key, value)
#    3447
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3628
#    3629             # turn me into an ndarray
# ...

# %%
Laptops1
# Out:
#                                                Laptop Rating Disc_price  \
# 0   Acer Predator Helios 300 Core i5 8th Gen - (8 ...    4.6    ₹55,990
# 1   MSI GS Core i7 8th Gen - (16 GB/512 GB SSD/Win...      4  ₹1,49,990
# 2   Asus FX503 Core i7 7th Gen - (8 GB/1 TB HDD/12...      5    ₹87,990
# 3   Asus TUF Core i5 8th Gen - (8 GB/1 TB HDD/128 ...    4.5    ₹66,990
# 4   Asus ROG Strix Edition Core i7 7th Gen - (8 GB...      4    ₹92,990
# 5   Asus ROG Core i7 7th Gen - (8 GB/1 TB HDD/Wind...    4.3  ₹1,07,990
# 6   Asus ROG Core i7 7th Gen - (8 GB/1 TB HDD/256 ...      3  ₹1,46,490
# 7   Acer Predator Helios 300 Core i5 7th Gen - (8 ...    4.5  ₹1,29,999
# 8   Acer Nitro 5 Core i5 7th Gen - (8 GB/1 TB HDD/...    4.5    ₹52,990
# 9   Asus TUF Core i5 8th Gen - (8 GB/1 TB HDD/128 ...    4.3    ₹72,990
# 10  MSI GL Series Core i7 7th Gen - (8 GB/1 TB HDD...    4.9    ₹83,990
# 11  MSI GE Core i7 8th Gen - (16 GB/1 TB HDD/512 G...    4.5  ₹1,79,990
# ...

# %%
L1 = Laptops1.append(Laptops, ignore_index=True)
L1
# Out:
# C:\Users\Yamini\Anaconda3\lib\site-packages\pandas\core\frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#    Disc_price                                             Laptop  \
# 0     ₹55,990  Acer Predator Helios 300 Core i5 8th Gen - (8 ...
# 1   ₹1,49,990  MSI GS Core i7 8th Gen - (16 GB/512 GB SSD/Win...
# 2     ₹87,990  Asus FX503 Core i7 7th Gen - (8 GB/1 TB HDD/12...
# 3     ₹66,990  Asus TUF Core i5 8th Gen - (8 GB/1 TB HDD/128 ...
# 4     ₹92,990  Asus ROG Strix Edition Core i7 7th Gen - (8 GB...
# 5   ₹1,07,990  Asus ROG Core i7 7th Gen - (8 GB/1 TB HDD/Wind...
# 6   ₹1,46,490  Asus ROG Core i7 7th Gen - (8 GB/1 TB HDD/256 ...
# 7   ₹1,29,999  Acer Predator Helios 300 Core i5 7th Gen - (8 ...
# ...

# %%
L1.shape
# Out:
# (58, 7)

# %%
print(Disc_price)
print(disc_price)
# Out:
# ['₹55,990', '₹1,49,990', '₹87,990', '₹66,990', '₹92,990', '₹1,07,990', '₹1,46,490', '₹1,29,999', '₹52,990', '₹72,990', '₹83,990', '₹1,79,990', '₹94,990', '₹68,990', '₹61,990', '₹72,990', '₹90,990', '₹54,990', '₹21,990', '₹19,990', '₹34,990', '₹34,990', '₹54,990', '₹23,990', '₹23,990', '₹25,990', '₹28,990', '₹44,990', '₹38,990', '₹41,990', '₹34,990', '₹39,990', '₹23,990', '₹29,990', '₹27,490', '₹19,990', '₹28,990', '₹54,990', '₹27,990', '₹69,990', '₹34,990']
# ₹34,990

# %%
for i in L1['Disc_price']:
    b=i.replace(",","")
    Disc_price.append(b)
    c = re.findall(r'\d+',b)
    Disc_price(c)

# %%
print(Disc_price)
# Out:
# ['₹55,990', '₹1,49,990', '₹87,990', '₹66,990', '₹92,990', '₹1,07,990', '₹1,46,490', '₹1,29,999', '₹52,990', '₹72,990', '₹83,990', '₹1,79,990', '₹94,990', '₹68,990', '₹61,990', '₹72,990', '₹90,990', '₹54,990', '₹21,990', '₹19,990', '₹34,990', '₹34,990', '₹54,990', '₹23,990', '₹23,990', '₹25,990', '₹28,990', '₹44,990', '₹38,990', '₹41,990', '₹34,990', '₹39,990', '₹23,990', '₹29,990', '₹27,490', '₹19,990', '₹28,990', '₹54,990', '₹27,990', '₹69,990', '₹34,990', '₹55990', '₹149990', '₹87990', '₹66990', '₹92990', '₹107990', '₹146490', '₹129999', '₹52990', '₹72990', '₹83990', '₹179990', '₹94990', '₹68990', '₹61990', '₹72990', '₹90990', '₹54990', '₹21990', '₹19990', '₹34990', '₹34990', '₹54990', '₹23990', '₹23990', '₹25990', '₹28990', '₹44990', '₹38990', '₹41990', '₹34990', '₹39990', '₹23990', '₹29990', '₹27490', '₹19990', '₹28990', '₹54990', '₹27990', '₹69990', '₹34990', '₹55990', '₹149990', '₹87990', '₹66990', '₹92990', '₹107990', '₹146490', '₹129999', '₹52990', '₹72990', '₹83990', '₹17999
# ...
