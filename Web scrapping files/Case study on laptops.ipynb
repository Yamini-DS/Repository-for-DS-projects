# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
L6 = pd.read_csv("Complete cleaned csv")
L6
# Out:
#      Unnamed: 0  Brands  Ram[GB]              Storage   Processor  \
# 0             0    Acer      8.0  1 TB HDD 128 GB SSD  i5 8th Gen
# 1             1     MSI     16.0           512 GB SSD  i7 8th Gen
# 2             2    Asus      8.0  1 TB HDD 128 GB SSD  i7 7th Gen
# 3             3    Asus      8.0  1 TB HDD 128 GB SSD  i5 8th Gen
# 4             4     MSI     16.0  1 TB HDD 512 GB SSD  i7 8th Gen
# ..          ...     ...      ...                  ...         ...
# 699         699    Asus      8.0  1 TB HDD 256 GB SSD  i7 8th Gen
# 700         700      HP      8.0             1 TB HDD  i5 8th Gen
# 701         701   Avita      8.0           256 GB SSD  i5 7th Gen
# 702         702     MSI     16.0             1 TB SSD  i7 9th Gen
# 703         703  Lenovo      8.0             1 TB HDD  i5 7th Gen
#
#                    Model  Rating  Disc_price  No of Ratings  No of Reviews  \
# 0    Predator Helios 300     4.6       55990        11530.0         1566.0
# ...

# %%
L6.drop(columns="Unnamed: 0",inplace=True)

# %%
L6.shape
# Out:
# (704, 10)

# %% [markdown]
# ### Laptops and preferences
# #### 1.Laptops whose storage is 512 GB SSD and some branded laptops whose rating is good

# %%
a1 =L6[(L6['Brands'].notnull()) & (L6["Rating"]>=4)&(L6["Storage"]=="512 GB SSD")]
a1
# Out:
#      Brands  Ram[GB]     Storage    Processor                    Model  \
# 1       MSI     16.0  512 GB SSD   i7 8th Gen                       GS
# 19     Acer      8.0  512 GB SSD   i5 8th Gen                Aspire 5s
# 21     Acer      8.0  512 GB SSD   i5 8th Gen                  Swift 3
# 23      MSI      8.0  512 GB SSD   i5 9th Gen                      ---
# 35     Asus      8.0  512 GB SSD   i5 9th Gen              ROG Strix G
# 37      MSI      8.0  512 GB SSD   i7 9th Gen                GF63 Thin
# 51     Asus     16.0  512 GB SSD   i7 9th Gen              ROG Strix G
# 61     Asus      8.0  512 GB SSD  i5 10th Gen              ZenBook Duo
# 73     Dell      8.0  512 GB SSD   i5 8th Gen  Inspiron 13 7000 Series
# 87     Asus      8.0  512 GB SSD   i5 9th Gen                ROG Strix
# 105  Lenovo      8.0  512 GB SSD   i5 8th Gen             Ideapad S340
# 111    Asus      8.0  512 GB SSD   i5 8th Gen               ZenBook 14
# ...

# %%
Prefer=L6[(L6['Rating']>=4.0)&(L6['Disc_price']<80000)]
Prefer.head()
# Out:
#    Brands  Ram[GB]              Storage   Processor                Model  \
# 0    Acer      8.0  1 TB HDD 128 GB SSD  i5 8th Gen  Predator Helios 300
# 3    Asus      8.0  1 TB HDD 128 GB SSD  i5 8th Gen                  TUF
# 10   Acer      8.0  1 TB HDD 128 GB SSD  i5 7th Gen              Nitro 5
# 11   Asus      8.0  1 TB HDD 128 GB SSD  i5 8th Gen                  TUF
# 13   Asus      8.0             1 TB HDD  i7 7th Gen                FX553
#
#     Rating  Disc_price  No of Ratings  No of Reviews Operating system
# 0      4.6       55990        11530.0         1566.0  Windows 10 Home
# 3      4.5       66990         1181.0          219.0  Windows 10 Home
# 10     4.5       52990          405.0           83.0  Windows 10 Home
# 11     4.3       72990           56.0            9.0  Windows 10 Home
# 13     4.4       68990          351.0           75.0       Windows 10

# %%
Prefer['Brands'].value_counts()
# Out:
# HP           163
# Asus         112
# Dell          61
# Lenovo        53
# Acer          43
# MSI           13
# Avita          8
# Microsoft      4
# Apple          2
# Name: Brands, dtype: int64

# %%
Prefer[(Prefer['Brands']=='Apple')]
# Out:
#     Brands  Ram[GB]     Storage   Processor        Model  Rating  Disc_price  \
# 17   Apple      8.0  128 GB SSD  i5 5th Gen  MacBook Air     4.7       54990
# 416  Apple      4.0  128 GB SSD  i5 5th Gen  MacBook Air     4.1       65900
#
#      No of Ratings  No of Reviews Operating system
# 17         20868.0         2411.0              Mac
# 416           48.0           10.0              Mac

# %%
Len=Prefer[(Prefer['Brands']=='Lenovo')&(Prefer['Operating system']=='Windows 10 Home')&(Prefer['Ram[GB]']>4.0)]
Len.head()
# Out:
#      Brands  Ram[GB]              Storage   Processor         Model  Rating  \
# 14   Lenovo      8.0  1 TB HDD 128 GB SSD  i5 7th Gen        Legion     4.6
# 30   Lenovo      8.0             1 TB HDD  i5 8th Gen   Ideapad 130     4.2
# 55   Lenovo      8.0             1 TB HDD  i5 8th Gen   Ideapad 330     4.2
# 78   Lenovo      8.0             1 TB HDD  i5 8th Gen   Legion Y530     4.2
# 105  Lenovo      8.0           512 GB SSD  i5 8th Gen  Ideapad S340     4.7
#
#      Disc_price  No of Ratings  No of Reviews Operating system
# 14        61990          359.0           88.0  Windows 10 Home
# 30        39990          646.0           67.0  Windows 10 Home
# 55        45990         4028.0          510.0  Windows 10 Home
# 78        49990           37.0            8.0  Windows 10 Home
# 105       54848           24.0            5.0  Windows 10 Home

# %%
Len.shape
# Out:
# (21, 10)

# %%
Len
# Out:
#      Brands  Ram[GB]              Storage   Processor         Model  Rating  \
# 14   Lenovo      8.0  1 TB HDD 128 GB SSD  i5 7th Gen        Legion     4.6
# 30   Lenovo      8.0             1 TB HDD  i5 8th Gen   Ideapad 130     4.2
# 55   Lenovo      8.0             1 TB HDD  i5 8th Gen   Ideapad 330     4.2
# 78   Lenovo      8.0             1 TB HDD  i5 8th Gen   Legion Y530     4.2
# 105  Lenovo      8.0           512 GB SSD  i5 8th Gen  Ideapad S340     4.7
# 123  Lenovo      8.0             1 TB HDD  i5 7th Gen           ---     4.8
# 159  Lenovo      8.0           256 GB SSD  i5 7th Gen           ---     4.4
# 180  Lenovo      8.0             2 TB HDD  i5 7th Gen   Ideapad 320     4.3
# 183  Lenovo      8.0           512 GB SSD  i5 8th Gen  Ideapad 530s     4.3
# 202  Lenovo      8.0             1 TB HDD  i5 7th Gen   Ideapad 320     4.4
# 226  Lenovo      8.0             1 TB HDD  i5 7th Gen  Ideapad 320E     4.1
# ...

# %%
L6[(L6['Rating']>=4.0)&(L6['Brands']=='Lenovo')&(L6['Ram[GB]']>8.0)]
# Out:
#      Brands  Ram[GB]              Storage   Processor     Model  Rating  \
# 285  Lenovo     16.0  1 TB HDD 128 GB SSD  i7 6th Gen  Y Series     4.3
#
#      Disc_price  No of Ratings  No of Reviews Operating system
# 285       99990           48.0           22.0  Windows 10 Home

# %%
L6[(L6['Rating']>=4.0)&(L6['Ram[GB]']>8.0)&(L6['Disc_price']<100000)&(L6['Brands']=='Microsoft')]
# Out:
# Empty DataFrame
# Columns: [Brands, Ram[GB], Storage, Processor, Model, Rating, Disc_price, No of Ratings, No of Reviews, Operating system]
# Index: []

# %%
L6[(L6['Brands']=='Microsoft')]
# Out:
#         Brands  Ram[GB]     Storage   Processor             Model  Rating  \
# 439  Microsoft      8.0  256 GB SSD  i5 8th Gen  Surface Laptop 2     0.0
# 576  Microsoft      8.0  128 GB SSD  i5 8th Gen     Surface Pro 6     4.9
# 620  Microsoft      8.0  256 GB SSD  i5 8th Gen     Surface Pro 6     0.0
# 664  Microsoft      8.0  128 GB SSD  i5 7th Gen           Surface     4.4
# 682  Microsoft      8.0  128 GB SSD  i5 8th Gen     Surface Pro 6     4.9
# 683  Microsoft      4.0  128 GB SSD  i5 7th Gen       Surface Pro     4.5
# 684  Microsoft      8.0  128 GB SSD  i5 7th Gen           Surface     4.4
# 685  Microsoft      8.0  128 GB SSD  i5 8th Gen  Surface Laptop 2     4.2
#
#      Disc_price  No of Ratings  No of Reviews Operating system
# 439      116990            0.0            0.0  Windows 10 Home
# 576       71890            8.0            1.0  Windows 10 Home
# 620      107990            0.0            0.0  Windows 10 Home
# ...

# %%
L6['Operating system'].value_counts()
# Out:
# Windows 10 Home    536
# DOS                 75
# Linux               37
# Mac                 15
# Windows 8 Pro       10
# Windows 10           9
# Windows 8            9
# Windows 10 Pro       8
# Ubuntu               3
# Windows 10 S         2
# Name: Operating system, dtype: int64

# %% [markdown]
# #### Brands and availability

# %%
a1["Brands"].value_counts()
# Out:
# MSI       12
# Asus       8
# Lenovo     3
# HP         2
# Acer       2
# Apple      2
# Dell       1
# Name: Brands, dtype: int64

# %% [markdown]
# #### Ratings and laptops

# %%
a1["Rating"].value_counts()
# Out:
# 4.6    6
# 4.8    5
# 4.5    5
# 4.7    4
# 4.4    2
# 4.3    2
# 4.0    2
# 4.1    1
# 4.2    1
# 4.9    1
# 5.0    1
# Name: Rating, dtype: int64

# %%
a1.describe()
# Out:
#          Ram[GB]     Rating    Disc_price  No of Ratings  No of Reviews
# count  30.000000  30.000000      30.00000      30.000000      30.000000
# mean    9.466667   4.550000   87197.30000     341.633333      55.266667
# std     3.059562   0.252914   41713.64618     793.220736     130.866853
# min     8.000000   4.000000   41990.00000       1.000000       0.000000
# 25%     8.000000   4.425000   57740.00000      10.250000       2.000000
# 50%     8.000000   4.600000   75120.50000      19.000000       5.000000
# 75%     8.000000   4.700000   95240.75000     239.250000      51.750000
# max    16.000000   5.000000  189990.00000    3682.000000     589.000000

# %%
a1.median()
# Out:
# Ram[GB]              8.0
# Rating               4.6
# Disc_price       75120.5
# No of Ratings       19.0
# No of Reviews        5.0
# dtype: float64

# %% [markdown]
# #### 2. Price starting from 80,000  and Lenovo brand be the requirements

# %%
a2=a1[(a1["Rating"]>=4.8)&(a1["Brands"].notnull())&(a1["Disc_price"]>150000)]
a2
# Out:
#     Brands  Ram[GB]     Storage   Processor        Model  Rating  Disc_price  \
# 225    MSI     16.0  512 GB SSD  i7 8th Gen           GS     4.8      189990
# 589    MSI     16.0  512 GB SSD  i7 8th Gen      Stealth     4.8      189990
# 691  Apple      8.0  512 GB SSD  i5 8th Gen  MacBook Pro     4.8      164990
#
#      No of Ratings  No of Reviews Operating system
# 225           13.0            3.0  Windows 10 Home
# 589            4.0            1.0  Windows 10 Home
# 691           39.0            6.0              Mac

# %%
L6[(L6["Disc_price"]>=75000)&(L6["Disc_price"]<150000)&(L6["Rating"]>4.8)&(L6["Ram[GB]"]>=8.0)]
# Out:
#      Brands  Ram[GB]              Storage   Processor                Model  \
# 2      Asus      8.0  1 TB HDD 128 GB SSD  i7 7th Gen                FX503
# 9       MSI      8.0  1 TB HDD 128 GB SSD  i7 7th Gen            GL Series
# 85     Acer     16.0  1 TB HDD 256 GB SSD  i7 9th Gen  Predator Helios 300
# 135    Dell      8.0           256 GB SSD  i7 8th Gen               XPS 15
# 153     MSI     16.0  1 TB HDD 128 GB SSD  i7 7th Gen                   GP
# 264     MSI     16.0  1 TB HDD 128 GB SSD  i7 7th Gen                   GP
# 392    Asus      8.0           512 GB SSD  i5 8th Gen           ZenBook 14
# 572    Acer      8.0  2 TB HDD 256 GB SSD  i7 9th Gen           Helios 300
# 598     MSI      8.0  1 TB HDD 128 GB SSD  i7 9th Gen                  ---
# 627  Lenovo      8.0           512 GB SSD  i5 8th Gen         Ideapad 720S
# 663      HP      8.0  1 TB HDD 256 GB SSD  i7 9th Gen             Pavilion
#
# ...

# %%
a2[(a2["Brands"]=="Lenovo")&(a2["Rating"]>4.8)&(a2["Disc_price"]>=80000)]
# Out:
# Empty DataFrame
# Columns: [Brands, Ram[GB], Storage, Processor, Model, Rating, Disc_price, No of Ratings, No of Reviews, Operating system]
# Index: []

# %% [markdown]
# ***** This is the laptop of Lenovo brand with i5 8th gen processor, Windows 10 Home OS, 8.0 GB RAM capacity and the best laptop by the given requirements.

# %% [markdown]
# ### 3. Good laptops with good processor,Ram of atleast 8 GB and storage of atleast 256 GB SSD/256 GB HDD

# %%
a2=L6[(L6['Brands'].notnull()) & (L6["Rating"]>=4)&(L6["No of Ratings"]>=1000)&(L6["No of Reviews"]>=1000)]
a2
# Out:
#      Brands  Ram[GB]              Storage   Processor                Model  \
# 0      Acer      8.0  1 TB HDD 128 GB SSD  i5 8th Gen  Predator Helios 300
# 17    Apple      8.0           128 GB SSD  i5 5th Gen          MacBook Air
# 34     Acer      8.0  1 TB HDD 128 GB SSD  i5 8th Gen  Predator Helios 300
# 41       HP      4.0             1 TB HDD  i3 7th Gen                  14q
# 42     Asus      8.0  1 TB HDD 256 GB SSD  i5 8th Gen    VivoBook S Series
# 43       HP      4.0             1 TB HDD  i3 7th Gen                  14q
# 49     Asus      8.0  1 TB HDD 256 GB SSD  i5 8th Gen    VivoBook S Series
# 54     Asus      8.0  1 TB HDD 256 GB SSD  i5 8th Gen    VivoBook S Series
# 62       HP      4.0             1 TB HDD  i3 7th Gen                  14q
# 86       HP      4.0             1 TB HDD  i3 7th Gen                  14q
# 110      HP      4.0             1 TB HDD  i3 7th Gen                  14q
# ...

# %%
a2.shape
# Out:
# (43, 10)

# %%
a2["Brands"].value_counts()
# Out:
# HP        36
# Asus       3
# Acer       2
# Lenovo     1
# Apple      1
# Name: Brands, dtype: int64

# %%
a2.describe()
# Out:
#          Ram[GB]     Rating    Disc_price  No of Ratings  No of Reviews
# count  43.000000  43.000000     43.000000      43.000000      43.000000
# mean    4.744186   4.248837  31915.697674    9836.418605    1309.418605
# std     1.574998   0.133403   8715.003168    2622.886026     596.883702
# min     4.000000   4.100000  26490.000000    6244.000000    1002.000000
# 25%     4.000000   4.200000  27990.000000    9365.000000    1131.000000
# 50%     4.000000   4.200000  27990.000000    9365.000000    1131.000000
# 75%     4.000000   4.200000  29019.000000    9365.000000    1131.000000
# max     8.000000   4.700000  55990.000000   20868.000000    3781.000000

# %% [markdown]
# a2[(a2["Ram[GB]"]>=8)&(a2["Storage"]=="256 GB SSD")|(a2["Storage"]=="256 GB HDD")]

# %%
a2[(a2["Ram[GB]"]>=8)&(a2["Storage"]=="512 GB SSD")]
# Out:
# Empty DataFrame
# Columns: [Brands, Ram[GB], Storage, Processor, Model, Rating, Disc_price, No of Ratings, No of Reviews, Operating system]
# Index: []

# %%
a3=a2[(a2["Ram[GB]"]>=8)&(a2["Brands"].notnull())]
a3
# Out:
#     Brands  Ram[GB]              Storage   Processor                Model  \
# 0     Acer      8.0  1 TB HDD 128 GB SSD  i5 8th Gen  Predator Helios 300
# 17   Apple      8.0           128 GB SSD  i5 5th Gen          MacBook Air
# 34    Acer      8.0  1 TB HDD 128 GB SSD  i5 8th Gen  Predator Helios 300
# 42    Asus      8.0  1 TB HDD 256 GB SSD  i5 8th Gen    VivoBook S Series
# 49    Asus      8.0  1 TB HDD 256 GB SSD  i5 8th Gen    VivoBook S Series
# 54    Asus      8.0  1 TB HDD 256 GB SSD  i5 8th Gen    VivoBook S Series
# 417     HP      8.0             1 TB HDD  i3 6th Gen                   15
# 450     HP      8.0             1 TB HDD  i3 6th Gen                  ---
#
#      Rating  Disc_price  No of Ratings  No of Reviews Operating system
# 0       4.6       55990        11530.0         1566.0  Windows 10 Home
# 17      4.7       54990        20868.0         2411.0              Mac
# 34      4.6       55990        11530.0         1566.0  Windows 10 Home
# ...

# %%
a3.drop(42,inplace=True)
# Out:
# C:\Users\Yamini\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
a3.drop(49,inplace=True)

# %%
a3.drop(0,inplace=True)

# %%
a3[(a3["Storage"]=="1 TB HDD")|(a3["Storage"]=="1 TB HDD 256 GB SSD")|(a3["Storage"]=="1 TB HDD 128 GB SSD")]
# Out:
#     Brands  Ram[GB]              Storage   Processor                Model  \
# 34    Acer      8.0  1 TB HDD 128 GB SSD  i5 8th Gen  Predator Helios 300
# 54    Asus      8.0  1 TB HDD 256 GB SSD  i5 8th Gen    VivoBook S Series
# 417     HP      8.0             1 TB HDD  i3 6th Gen                   15
# 450     HP      8.0             1 TB HDD  i3 6th Gen                  ---
#
#      Rating  Disc_price  No of Ratings  No of Reviews Operating system
# 34      4.6       55990        11530.0         1566.0  Windows 10 Home
# 54      4.5       49990         7108.0         1002.0  Windows 10 Home
# 417     4.2       33996         8463.0         1461.0              DOS
# 450     4.2       33724        17432.0         3781.0              DOS

# %% [markdown]
# *****From all the above 4 laptops I would say the better laptop to purchase Asus laptop of 256 GB SSD(as per the requirement).

# %% [markdown]
# ### 4. Apple laptop with good storage and RAM capacity greater than 8 GB and latest Model

# %%
a4 = L6[(L6["Brands"]=="Apple")&(L6["Ram[GB]"]>8)&(L6["Storage"].notnull())]
a4
# Out:
#     Brands  Ram[GB]                Storage          Processor        Model  \
# 320  Apple     16.0  512 GB HDD 512 GB SSD         i7 5th Gen  MacBook Pro
# 428  Apple     16.0             256 GB SSD         i7 8th Gen  MacBook Pro
# 484  Apple     16.0             512 GB SSD         i7 7th Gen  MacBook Pro
# 654  Apple     16.0             512 GB SSD         i7 7th Gen  MacBook Pro
# 672  Apple     16.0             512 GB SSD  i7 Processor16 GB  Macbook Pro
#
#      Rating  Disc_price  No of Ratings  No of Reviews Operating system
# 320     3.7      199900           38.0           19.0              Mac
# 428     5.0      189990           12.0            1.0              Mac
# 484     0.0      212449            0.0            0.0              Mac
# 654     0.0      229990            0.0            0.0              Mac
# 672     3.3      168299           78.0           40.0              Mac

# %%
a4.replace(to_replace="i7 Processor16 GB",value="i7 Processor",inplace=True)
L6.replace(to_replace="i7 Processor16 GB",value="i7 Processor",inplace=True)
# Out:
# C:\Users\Yamini\Anaconda3\lib\site-packages\pandas\core\frame.py:4042: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   method=method)

# %%
a4
# Out:
#     Brands  Ram[GB]                Storage     Processor        Model  Rating  \
# 320  Apple     16.0  512 GB HDD 512 GB SSD    i7 5th Gen  MacBook Pro     3.7
# 428  Apple     16.0             256 GB SSD    i7 8th Gen  MacBook Pro     5.0
# 484  Apple     16.0             512 GB SSD    i7 7th Gen  MacBook Pro     0.0
# 654  Apple     16.0             512 GB SSD    i7 7th Gen  MacBook Pro     0.0
# 672  Apple     16.0             512 GB SSD  i7 Processor  Macbook Pro     3.3
#
#      Disc_price  No of Ratings  No of Reviews Operating system
# 320      199900           38.0           19.0              Mac
# 428      189990           12.0            1.0              Mac
# 484      212449            0.0            0.0              Mac
# 654      229990            0.0            0.0              Mac
# 672      168299           78.0           40.0              Mac

# %% [markdown]
# ***** There are 6 laptops available of this type and from these the latest model would be 2,3,4,5 laptops and high storage is available in 3,4,5 laptops. According to the rating and affordibility of the laptops from these three I can say 5th Macbook Pro of 512 GB SSD, i7 Processor can be purchased if not 4,5 are good laptops with latest model and by the price I can say that 4th has more features so this is good to purchase.

# %%
L6[(L6["Disc_price"]<50000)&(L6["Rating"]>4.5)]
# Out:
#      Brands  Ram[GB]                Storage   Processor          Model  \
# 21     Acer      8.0             512 GB SSD  i5 8th Gen        Swift 3
# 121    Acer      8.0               1 TB HDD  i5 8th Gen        Nitro 5
# 230  Lenovo      4.0  16 GB Optane 1 TB HDD  i5 8th Gen    Ideapad 330
# 371    Dell      4.0               1 TB HDD  i5 6th Gen            ---
# 410    Dell      4.0               1 TB HDD  i3 5th Gen         Vostro
# 470    Dell      4.0               1 TB HDD  i3 5th Gen         Vostro
# 573    Asus      2.0             500 GB HDD  i3 4th Gen         X554LD
# 671      HP      4.0             256 GB SSD  i3 8th Gen  Pavilion x360
#
#      Rating  Disc_price  No of Ratings  No of Reviews Operating system
# 21      4.6       44990         2341.0          429.0  Windows 10 Home
# 121     4.7       47490            7.0            1.0  Windows 10 Home
# 230     4.7       49990            6.0            1.0  Windows 10 Home
# ...

# %%
L6[(L6["Brands"]=="Apple")]
# Out:
#     Brands  Ram[GB]                Storage     Processor             Model  \
# 17   Apple      8.0             128 GB SSD    i5 5th Gen       MacBook Air
# 107  Apple      8.0             256 GB SSD    i5 8th Gen       Macbook Pro
# 194  Apple      8.0             256 GB SSD    i5 8th Gen       MacBook Air
# 244  Apple      8.0             512 GB SSD    i5 7th Gen           MacBook
# 320  Apple     16.0  512 GB HDD 512 GB SSD    i7 5th Gen       MacBook Pro
# 359  Apple      8.0             512 GB SSD    i5 5th Gen  MacBook Pro 2015
# 416  Apple      4.0             128 GB SSD    i5 5th Gen       MacBook Air
# 428  Apple     16.0             256 GB SSD    i7 8th Gen       MacBook Pro
# 484  Apple     16.0             512 GB SSD    i7 7th Gen       MacBook Pro
# 644  Apple      8.0             128 GB SSD    i5 8th Gen       MacBook Pro
# 654  Apple     16.0             512 GB SSD    i7 7th Gen       MacBook Pro
# ...
